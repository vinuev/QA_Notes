# %% [markdown]
# ### get_GST_from_QKG_with_Frozenset.py
# ### def call_main_GST(f1, f2, f4, f5, no_GST, gdict, verbose, gt1, config, context_file):
# ### graph_node,graph_edge,GST_match_flag, candidate_match_flag1, top_match_flag1, candidate_match_flag2, top_match_flag2, candidate_match_flag3, top_match_flag3, candidate_match_flag4, top_match_flag4, candidate_match_flag5, top_match_flag5 = call_main_GST(QKG_file, cornerstone_file, qtype, answer_list_file, no_GST, gdict, verbose,gt,config,con)
# ### call_main_GST(QKG_file, cornerstone_file, qtype, answer_list_file, no_GST, gdict, verbose,gt,config,con)
#     f1, f2, f4, f5, no_GST, gdict, verbose, gt1, config, context_file
#         f1=argv[1] #input QKG
#         f2=argv[2] #input Cornerstones
#         f4=argv[3] #answer match / qtype
#         f5=argv[4] #answer type /answer_list_file
#         no_GST=int(argv[5]) #number of GSTs
#
#         verbose=int(argv[6])
#     QKG_file, cornerstone_file, qtype, answer_list_file, no_GST, gdict, verbose,gt,config,con

# %%
import gensim
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec
# from stanfordcorenlp import StanfordCoreNLP
# nlp = StanfordCoreNLP(r'stanford-corenlp-full-2018-10-05')

# %%
import networkx as nx
from heapq import heappush, heappop, heapify
import Queue
import pickle
import sys
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
f1 = "./files/QKG_ques-q1"
f2 = "./files/QKG_cornerstones_ques-q1"
f4 = "question_type.txt"
f5 = "./files/Answer_list_ques-q1"
no_GST = 50 #Number of GSTs to be considered 
# if embedding=='WORD2VEC':
# gdict={}
# model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)  
# word_vectors = model.wv
# gdict=word_vectors

verbose = 0
gt = set(['unknown'])

stream=open("config.yml", 'r')

for line in stream:
    if not line.startswith('#') and len(line)>1:
        #print 'line ',line
        line=line.split(':')
        config[line[0]]=line[1].strip()

con="./files/context_ques-q1"
# Out:
# /usr/local/anaconda3/envs/QUES_Test/lib/python2.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-293b0dc59d44> in <module>()
#      18         #print 'line ',line
#      19         line=line.split(':')
# ---> 20         config[line[0]]=line[1].strip()
#      21
#      22 con="./files/context_ques-q1"
#
# NameError: name 'config' is not defined

# %%
config={}
for line in stream:
    if not line.startswith('#') and len(line)>1:
        #print 'line ',line
        line=line.split(':')
        config[line[0]]=line[1].strip()

# %%
gdict={}
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)  
word_vectors = model.wv
gdict=word_vectors

# %%
gdict

# %%
threshold = float(config['Cosine_threshold'])
MAX_MATCH = int(config['Embedding_Similarity'])
# Type filtering can be none (0), Relaxed i.e. only apply if candidate list greater than 10 (1), or Strict i.e. apply always (2)
Type_Filtering_flag = int(config['Type_Filtering'])
Distribute_Node_wt_flag = int(config['Distribute_Node_wt'])
chain_join_flag = int(config['chain_join_flag'])

# %%
threshold
# Out:
# 0.75

# %%
# try:
G1 = nx.read_gpickle(f1)
if verbose:
    print "\n\nSize of the read graph ", len(G1.nodes()), len(G1.edges())
corner1 = pickle.load(open(f2, 'r'))

# except:
#     if verbose:
#         print "No graph or Cornerstones\n"
#     answer_list = []
#     pickle.dump(answer_list, open(f5, 'w'))
#     return

# %%
corner1
# Out:
# {u'11 steve jobs:Entity': 'steve jobs',
#  u'1985 jobs:Entity': 'steve jobs',
#  u'1986 jobs:Entity': 'steve jobs',
#  u'2003 jobs:Entity': 'steve jobs',
#  u'2009 jobs:Entity': 'steve jobs',
#  u'actor steve carell:Entity': 'steve jobs',
#  u'adoption jobs:Entity': 'steve jobs',
#  u'after jobs:Entity': 'steve jobs',
#  u'apple co-founder 06 oct 2011 steve jobs:Entity': 'steve jobs',
#  u'apple co-founder steve jobs:Entity': 'steve jobs',
#  u'apple jobs:Entity': 'steve jobs',
#  u'biological father steve jobs:Entity': 'steve jobs',
#  u'birth after:Predicate:1': 'born',
#  u'birth family during:Predicate:1': 'born',
#  u'birth father:Predicate:1': 'born',
#  u'birth mother out:Predicate:1': 'born',
#  u'book steve jobs 2011:Entity': 'steve jobs',
#  u'book steve jobs:Predicate:1': 'steve jobs',
#  u'born in:Predicate:1': 'born',
#  u'born in:Predicate:2': 'born',
#  u'born in:Predicate:3': 'born',
#  u'born in:Predicate:4': 'born',
#  u'born in:Predicate:5': 'born',
#  u'born in:Predicate:6': 'born',
#  u'born in:Predicate:7': 'born',
#  u'born in:Predicate:8': 'born',
#  u'born into:Predicate:1': 'born',
#  u'born on:Predicate:1': 'born',
#  u'born on:Predicate:10': 'born',
#  u'born on:Predicate:2': 'born',
#  u'born on:Predicate:3': 'born',
#  u'born on:Predicate:4': 'born',
#  u'born on:Predicate:5': 'born',
#  u'born on:Predicate:6': 'born',
#  u'born on:Predicate:7': 'born',
#  u'born on:Predicate:8': 'born',
#  u'born on:Predicate:9': 'born',
#  u'born out:Predicate:1': 'born',
#  u'born:Predicate:1': 'born',
#  u'born:Predicate:2': 'born',
#  u'born:Predicate:3': 'born',
#  u'born:Predicate:4': 'born',
#  u'born:Predicate:5': 'born',
#  u'born:Predicate:6': 'born',
#  u'born:Predicate:7': 'born',
#  u'born:Predicate:8': 'born',
#  u'born:Predicate:9': 'born',
#  u'brennan-jobs by:Predicate:1': 'steve jobs',
#  u'british-born industrial designer:Entity': 'born',
#  u'children jobs:Entity': 'steve jobs',
#  u'clara jobs:Entity': 'steve jobs',
#  u'death jobs:Entity': 'steve jobs',
#  u'designs jobs:Entity': 'steve jobs',
#  u'different jobs:Entity': 'steve jobs',
#  u'disney steve jobs:Entity': 'steve jobs',
#  u'edward c. steve jobs:Entity': 'steve jobs',
#  u'emigrated from:Predicate:1': 'born',
#  u'emotional jobs:Entity': 'steve jobs',
#  u'favorite steve jobs memory:Entity': 'steve jobs',
#  u'first jobs:Entity': 'steve jobs',
#  u'friend steve jobs:Entity': 'steve jobs',
#  u'january 1984 jobs:Entity': 'steve jobs',
#  u'job as:Predicate:1': 'steve jobs',
#  u'job at:Predicate:1': 'steve jobs',
#  u'job with:Predicate:1': 'steve jobs',
#  u'jobs as:Predicate:1': 'steve jobs',
#  u'jobs as:Predicate:2': 'steve jobs',
#  u'jobs as:Predicate:3': 'steve jobs',
#  u'jobs at:Predicate:1': 'steve jobs',
#  u'jobs because:Predicate:1': 'steve jobs',
#  u'jobs biography:Entity': 'steve jobs',
#  u'jobs by:Predicate:1': 'steve jobs',
#  u'jobs convinced wozniak:Entity': 'steve jobs',
#  u'jobs disney:Entity': 'steve jobs',
#  u'jobs family:Entity': 'steve jobs',
#  u'jobs first:Entity': 'steve jobs',
#  u'jobs from:Predicate:1': 'steve jobs',
#  u'jobs in:Predicate:1': 'steve jobs',
#  u'jobs in:Predicate:2': 'steve jobs',
#  u'jobs in:Predicate:3': 'steve jobs',
#  u'jobs in:Predicate:4': 'steve jobs',
#  u'jobs in:Predicate:5': 'steve jobs',
#  u'jobs in:Predicate:6': 'steve jobs',
#  u'jobs in:Predicate:7': 'steve jobs',
#  u'jobs obit:Entity': 'steve jobs',
#  u'jobs of:Predicate:1': 'steve jobs',
#  u'jobs on:Predicate:1': 'steve jobs',
#  u'jobs on:Predicate:2': 'steve jobs',
#  u'jobs on:Predicate:3': 'steve jobs',
#  u'jobs once:Entity': 'steve jobs',
#  u'jobs outside:Predicate:1': 'steve jobs',
#  u'jobs powerless within:Predicate:1': 'steve jobs',
#  u'jobs steve jobs:Entity': 'steve jobs',
#  u'jobs that:Predicate:1': 'steve jobs',
#  u'jobs that:Predicate:2': 'steve jobs',
#  u'jobs through:Predicate:1': 'steve jobs',
#  u'jobs until:Predicate:1': 'steve jobs',
#  u'jobs while:Predicate:1': 'steve jobs',
#  u'jobs while:Predicate:2': 'steve jobs',
#  u'jobs while:Predicate:3': 'steve jobs',
#  u'jobs while:Predicate:4': 'steve jobs',
#  u'last words jobs:Entity': 'steve jobs',
#  u'lisa brennan jobs:Entity': 'steve jobs',
#  u'lost steve jobs speech from:Predicate:1': 'steve jobs',
#  u'married because:Predicate:1': 'born',
#  u'married in:Predicate:1': 'born',
#  u'married in:Predicate:2': 'born',
#  u'married in:Predicate:3': 'born',
#  u'married on:Predicate:1': 'born',
#  u'married with:Predicate:1': 'born',
#  u'married with:Predicate:2': 'born',
#  u'married:Predicate:1': 'born',
#  u'married:Predicate:2': 'born',
#  u'married:Predicate:3': 'born',
#  u'married:Predicate:4': 'born',
#  u'married:Predicate:5': 'born',
#  u'married:Predicate:6': 'born',
#  u'married:Predicate:7': 'born',
#  u'married:Predicate:8': 'born',
#  u'massive layoffs clear out:Predicate:1': 'steve jobs',
#  u'massive layoffs clear out:Predicate:2': 'steve jobs',
#  u'name jobs:Entity': 'steve jobs',
#  u'names jobs as:Predicate:1': 'steve jobs',
#  u'one jobs:Entity': 'steve jobs',
#  u'paul jobs:Entity': 'steve jobs',
#  u'paul reinhold jobs:Entity': 'steve jobs',
#  u'pixar ceo steve jobs:Entity': 'steve jobs',
#  u'pixar jobs:Entity': 'steve jobs',
#  u'private steve jobs memorial:Entity': 'steve jobs',
#  u'profitability jobs on:Predicate:1': 'steve jobs',
#  u'profitability jobs on:Predicate:2': 'steve jobs',
#  u'profitability jobs on:Predicate:3': 'steve jobs',
#  u'rebellious jobs:Entity': 'steve jobs',
#  u'sister patti jobs:Entity': 'steve jobs',
#  u'sizes jobs:Entity': 'steve jobs',
#  u'steve jobs 1955-2011:Entity': 'steve jobs',
#  u'steve jobs 1955:Entity': 'steve jobs',
#  u'steve jobs aug 21 , 2019 apr 27 , 2017 steve jobs:Entity': 'steve jobs',
#  u'steve jobs back:Entity': 'steve jobs',
#  u'steve jobs bio:Entity': 'steve jobs',
#  u'steve jobs biological father:Entity': 'steve jobs',
#  u'steve jobs birthday:Entity': 'steve jobs',
#  u'steve jobs disambiguation american entrepreneur:Entity': 'steve jobs',
#  u'steve jobs down:Entity': 'steve jobs',
#  u'steve jobs ezoic:Entity': 'steve jobs',
#  u'steve jobs fact card steve jobs:Entity': 'steve jobs',
#  u'steve jobs isaacson:Entity': 'steve jobs',
#  u'steve jobs media:Entity': 'steve jobs',
#  u'steve jobs memorial service:Entity': 'steve jobs',
#  u'steve jobs press release:Entity': 'steve jobs',
#  u'steve jobs regretted delaying cancer surgery 9 months:Entity': 'steve jobs',
#  u'steve jobs significant:Entity': 'steve jobs',
#  u'steve jobs so:Predicate:1': 'steve jobs',
#  u'steve jobs statue:Entity': 'steve jobs',
#  u'steve jobs story:Entity': 'steve jobs',
#  u'steve jobs taught:Entity': 'steve jobs',
#  u'steve jobs the new york times:Entity': 'steve jobs',
#  u'steve jobs the times of:Predicate:1': 'steve jobs',
#  u'steve jobs theatre:Entity': 'steve jobs',
#  u'steve jobs timeline of:Predicate:1': 'steve jobs',
#  u'steve jobs today:Entity': 'steve jobs',
#  u'steve jobs told me:Entity': 'steve jobs',
#  u'steve jobs will:Entity': 'steve jobs',
#  u'steve jobs:Entity': 'steve jobs',
#  u'steve thumbs:Entity': 'steve jobs',
#  u'steven levy:Predicate:1': 'steve jobs',
#  u'subsequent years jobs:Entity': 'steve jobs',
#  u'thinner steve jobs:Entity': 'steve jobs',
#  u'though steve:Entity': 'steve jobs',
#  u'upon jobs:Entity': 'steve jobs',
#  u'vault.fbi.gov steve jobs commencement speech:Entity': 'steve jobs',
#  u'visionary steve jobs:Entity': 'steve jobs',
#  u'wikiversity steve jobs:Entity': 'steve jobs',
#  u'wozniak jobs:Entity': 'steve jobs',
#  u'writer steve martin:Entity': 'steve jobs',
#  u'young jobs:Entity': 'steve jobs',
#  u'young steve jobs:Entity': 'steve jobs'}

# %%
corner = corner1
if verbose:
    print "\n\nSize of the unconverted directed graph, Number of cornerstones ", len(G1.nodes()), len(
        G1.edges()), len(corner)
# G=G1.to_undirected() #make QKG Undirected
# G=directed_to_undirected(G1)
G = G1

# %%
def initialize_queue(G, corner):
    Q = []
    T = {}
    for v in corner:
        T[v] = {}
        g = nx.Graph()
        g.add_node(v)  # access weight from G if needed
        p = frozenset([corner[v]])  # Query term
        T[v][p] = g
        c = get_cost(g, G)
        heappush(Q, (c, v, p))

    for v in T:
        if verbose:
            print "Vertex ", v
        for p in T[v]:
            if verbose:
                print "Query and tree --->", p, T[v][p].nodes(), T[v][p].edges()
    if verbose:
        print "Queue --->", Q
    return T, Q

# %%
def get_cost(t, G):
    c = 0.0
    for (n1, n2) in t.edges():
        if (n1, n2) in G.edges():
            data = G.get_edge_data(n1, n2)
        else:
            data = G.get_edge_data(n2, n1)
        for d in data['wlist']:  # Use if sum of cost is needed
            # d=data['weight']
            c += 1 - d  # cost=1-weight
    # if d==0:
    #	print "Edge d 0",data['weight'],data['wlist'],data['etype'],n1,n2
    # c+=1-d
    if c < 0:
        if verbose:
            print "\n\n ==== =========== ERROR NEG COST ===== \n\n", c

    if Distribute_Node_wt_flag == 1:
        for n in t.nodes():
            node_weight = G.node[n]['weight']
            # if node_weight>1:
            #	node_weight=1
            c += 1 - node_weight
        if c < 0:
            if verbose:
                print "\n\n ==== =========== ERROR NEG COST Node===== \n\n", c

    return c

# %%
if verbose:
    print "\n\nSize of the converted undirected graph largest connected component, Number of cornerstones ", len(
        G.nodes()), len(G.edges()), len(corner), corner

T, Q = initialize_queue(G, corner)
P = set()  # Entire query
for v in corner:
    P.add(corner[v])

if verbose:
    print P

count = {}
for v in corner:
    if corner[v] not in count:
        count[corner[v]] = set()
    count[corner[v]].add(v)

if verbose:
    print "\n\nCorner stone count per query term -->", count

# %%
count
# Out:
# {'born': {u'birth after:Predicate:1',
#   u'birth family during:Predicate:1',
#   u'birth father:Predicate:1',
#   u'birth mother out:Predicate:1',
#   u'born in:Predicate:1',
#   u'born in:Predicate:2',
#   u'born in:Predicate:3',
#   u'born in:Predicate:4',
#   u'born in:Predicate:5',
#   u'born in:Predicate:6',
#   u'born in:Predicate:7',
#   u'born in:Predicate:8',
#   u'born into:Predicate:1',
#   u'born on:Predicate:1',
#   u'born on:Predicate:10',
#   u'born on:Predicate:2',
#   u'born on:Predicate:3',
#   u'born on:Predicate:4',
#   u'born on:Predicate:5',
#   u'born on:Predicate:6',
#   u'born on:Predicate:7',
#   u'born on:Predicate:8',
#   u'born on:Predicate:9',
#   u'born out:Predicate:1',
#   u'born:Predicate:1',
#   u'born:Predicate:2',
#   u'born:Predicate:3',
#   u'born:Predicate:4',
#   u'born:Predicate:5',
#   u'born:Predicate:6',
#   u'born:Predicate:7',
#   u'born:Predicate:8',
#   u'born:Predicate:9',
#   u'british-born industrial designer:Entity',
#   u'emigrated from:Predicate:1',
#   u'married because:Predicate:1',
#   u'married in:Predicate:1',
#   u'married in:Predicate:2',
#   u'married in:Predicate:3',
#   u'married on:Predicate:1',
#   u'married with:Predicate:1',
#   u'married with:Predicate:2',
#   u'married:Predicate:1',
#   u'married:Predicate:2',
#   u'married:Predicate:3',
#   u'married:Predicate:4',
#   u'married:Predicate:5',
#   u'married:Predicate:6',
#   u'married:Predicate:7',
#   u'married:Predicate:8'},
#  'steve jobs': {u'11 steve jobs:Entity',
#   u'1985 jobs:Entity',
#   u'1986 jobs:Entity',
#   u'2003 jobs:Entity',
#   u'2009 jobs:Entity',
#   u'actor steve carell:Entity',
#   u'adoption jobs:Entity',
#   u'after jobs:Entity',
#   u'apple co-founder 06 oct 2011 steve jobs:Entity',
#   u'apple co-founder steve jobs:Entity',
#   u'apple jobs:Entity',
#   u'biological father steve jobs:Entity',
#   u'book steve jobs 2011:Entity',
#   u'book steve jobs:Predicate:1',
#   u'brennan-jobs by:Predicate:1',
#   u'children jobs:Entity',
#   u'clara jobs:Entity',
#   u'death jobs:Entity',
#   u'designs jobs:Entity',
#   u'different jobs:Entity',
#   u'disney steve jobs:Entity',
#   u'edward c. steve jobs:Entity',
#   u'emotional jobs:Entity',
#   u'favorite steve jobs memory:Entity',
#   u'first jobs:Entity',
#   u'friend steve jobs:Entity',
#   u'january 1984 jobs:Entity',
#   u'job as:Predicate:1',
#   u'job at:Predicate:1',
#   u'job with:Predicate:1',
#   u'jobs as:Predicate:1',
#   u'jobs as:Predicate:2',
#   u'jobs as:Predicate:3',
#   u'jobs at:Predicate:1',
#   u'jobs because:Predicate:1',
#   u'jobs biography:Entity',
#   u'jobs by:Predicate:1',
#   u'jobs convinced wozniak:Entity',
#   u'jobs disney:Entity',
#   u'jobs family:Entity',
#   u'jobs first:Entity',
#   u'jobs from:Predicate:1',
#   u'jobs in:Predicate:1',
#   u'jobs in:Predicate:2',
#   u'jobs in:Predicate:3',
#   u'jobs in:Predicate:4',
#   u'jobs in:Predicate:5',
#   u'jobs in:Predicate:6',
#   u'jobs in:Predicate:7',
#   u'jobs obit:Entity',
#   u'jobs of:Predicate:1',
#   u'jobs on:Predicate:1',
#   u'jobs on:Predicate:2',
#   u'jobs on:Predicate:3',
#   u'jobs once:Entity',
#   u'jobs outside:Predicate:1',
#   u'jobs powerless within:Predicate:1',
#   u'jobs steve jobs:Entity',
#   u'jobs that:Predicate:1',
#   u'jobs that:Predicate:2',
#   u'jobs through:Predicate:1',
#   u'jobs until:Predicate:1',
#   u'jobs while:Predicate:1',
#   u'jobs while:Predicate:2',
#   u'jobs while:Predicate:3',
#   u'jobs while:Predicate:4',
#   u'last words jobs:Entity',
#   u'lisa brennan jobs:Entity',
#   u'lost steve jobs speech from:Predicate:1',
#   u'massive layoffs clear out:Predicate:1',
#   u'massive layoffs clear out:Predicate:2',
#   u'name jobs:Entity',
#   u'names jobs as:Predicate:1',
#   u'one jobs:Entity',
#   u'paul jobs:Entity',
#   u'paul reinhold jobs:Entity',
#   u'pixar ceo steve jobs:Entity',
#   u'pixar jobs:Entity',
#   u'private steve jobs memorial:Entity',
#   u'profitability jobs on:Predicate:1',
#   u'profitability jobs on:Predicate:2',
#   u'profitability jobs on:Predicate:3',
#   u'rebellious jobs:Entity',
#   u'sister patti jobs:Entity',
#   u'sizes jobs:Entity',
#   u'steve jobs 1955-2011:Entity',
#   u'steve jobs 1955:Entity',
#   u'steve jobs aug 21 , 2019 apr 27 , 2017 steve jobs:Entity',
#   u'steve jobs back:Entity',
#   u'steve jobs bio:Entity',
#   u'steve jobs biological father:Entity',
#   u'steve jobs birthday:Entity',
#   u'steve jobs disambiguation american entrepreneur:Entity',
#   u'steve jobs down:Entity',
#   u'steve jobs ezoic:Entity',
#   u'steve jobs fact card steve jobs:Entity',
#   u'steve jobs isaacson:Entity',
#   u'steve jobs media:Entity',
#   u'steve jobs memorial service:Entity',
#   u'steve jobs press release:Entity',
#   u'steve jobs regretted delaying cancer surgery 9 months:Entity',
#   u'steve jobs significant:Entity',
#   u'steve jobs so:Predicate:1',
#   u'steve jobs statue:Entity',
#   u'steve jobs story:Entity',
#   u'steve jobs taught:Entity',
#   u'steve jobs the new york times:Entity',
#   u'steve jobs the times of:Predicate:1',
#   u'steve jobs theatre:Entity',
#   u'steve jobs timeline of:Predicate:1',
#   u'steve jobs today:Entity',
#   u'steve jobs told me:Entity',
#   u'steve jobs will:Entity',
#   u'steve jobs:Entity',
#   u'steve thumbs:Entity',
#   u'steven levy:Predicate:1',
#   u'subsequent years jobs:Entity',
#   u'thinner steve jobs:Entity',
#   u'though steve:Entity',
#   u'upon jobs:Entity',
#   u'vault.fbi.gov steve jobs commencement speech:Entity',
#   u'visionary steve jobs:Entity',
#   u'wikiversity steve jobs:Entity',
#   u'wozniak jobs:Entity',
#   u'writer steve martin:Entity',
#   u'young jobs:Entity',
#   u'young steve jobs:Entity'}}

# %%
def get_GST(Q, T, P, G, no_GST, corner, verbose):
    pop_hist = {}
    ite = 0
    pop_cov = -1
    merge_cov = -1
    min_cost = 999999
    GST_count = 0
    GST_set = []
    final_GST_cost = -99999
    final_GST_flag = 0
    leave_loop = 0

    while len(Q) > 0:
        x = heappop(Q)

        cc = x[0]
        v = x[1]
        p = x[2]

        if verbose:
            print "======================================================================================>>>>>>>>>"
        if verbose:
            print "iteration ->", ite
        ite += 1
        if verbose:
            print "\n\nPopped --->", x[0], x[1], x[2], len(p.intersection(P)), len(P), len(
                Q), pop_cov, merge_cov, min_cost
        if len(p) > pop_cov:
            pop_cov = len(p)
            if verbose:
                print "pop length increased to ", len(p)

        check = check_history(pop_hist, v, p)
        if check == 0:
            continue  # To avoid executing same pop
        if v not in pop_hist:
            pop_hist[v] = set()
        pop_hist[v].add(p)

        if p == P:
            current_cost = get_cost(T[v][p], G)
            # print '\nCurrent Cost ',current_cost,len(GST_set),GST_count,v,p
            # for (n1,n2) in T[v][p].edges():
            # data=G.get_edge_data(n1,n2)
            # print "Tree edge ",n1,n2,data['weight'],data['wlist'],data['etype']
            if final_GST_cost > -99999 and current_cost > final_GST_cost:  # No more GST with same cost as final GST
                leave_loop = 1
                break

            GST_set, New_GST_flag, pot_ans_flag = save_GST(GST_set, v, T[v][p], corner, G)
            if New_GST_flag == 1 and pot_ans_flag == 1:
                GST_count += 1
            if GST_count == no_GST and final_GST_flag == 0:
                final_GST_cost = get_cost(T[v][p], G)
                final_GST_flag = 1

        if leave_loop == 1:
            break
        # GROW
        for u in G.neighbors(v):
            if verbose:
                print "\nneighbor ", u, T[v][p].nodes(), T[v][p].edges(), len(Q)
            # gflag=0
            g = grow_graph(T[v][p], v, u)  # Crete temporary merge tree/graph
            if verbose:
                print "\nGrown ", v, p, g.nodes(), g.edges(), len(Q)
            cg = get_cost(g, G)
            flag = 0
            if u in T and p in T[u]:
                cu = get_cost(T[u][p], G)
                if cg < cu:  # If T[u][p] already exists, check if cost(merged_graph)<T[u][p]; in that case update T[u][p]
                    if verbose:
                        print "\nBefore Growth updated ", u, p, cg, cu, T[u][p].nodes(), T[u][p].edges(), get_cost(
                            T[u][p], G), len(Q)
                    T[u][p] = g
                    flag = 1
                    if verbose:
                        print "\nAfter Growth updated ", u, p, cg, cu, T[u][p].nodes(), T[u][p].edges(), get_cost(
                            T[u][p], G), len(Q)
                    Q = update_queue(Q, cg, u, p)
                    if len(p) == len(P) and cg < min_cost:
                        min_cost = cg
                    # print "Min cost updated by growth ",min_cost
            else:  # If T[u][p] does not exist, create T[u][p]=merged graph
                # if gflag==1:
                if u not in T:
                    T[u] = {}
                T[u][p] = g
                flag = 1
                # if flag==1:
                heappush(Q, (cg, u, p))

                if verbose:
                    print "\nGrowth created new root, query", u, p, cg, T[u][p].nodes(), T[u][p].edges(), get_cost(
                        T[u][p], G), len(Q)
                if len(p) == len(P) and cg < min_cost:
                    min_cost = cg
                # print "Min cost created by growth ",min_cost

        # MERGE
        p1 = p

        all_p2 = set()
        for p2 in T[v]:
            all_p2.add(p2)

        for p2 in all_p2:  # because T[v] changes during iteration
            if len(p1.intersection(p2)) == 0:
                # mflag=0
                g = merge_graph(T[v][p1], T[v][p2])
                cg = get_cost(g, G)
                p = frozenset(p1.union(p2))
                if p in T[v]:  # all_p2:
                    cp = get_cost(T[v][p], G)
                    if cg < cp:
                        if verbose:
                            print "\nBefore merge updated", v, p, cg, cp, T[v][p].nodes(), T[v][p].edges(), get_cost(
                                T[v][p], G), len(Q)
                        T[v][p] = g
                        # heappush(Q,(cg,v,pp))
                        Q = update_queue(Q, cg, v, p)
                        if verbose:
                            print "\nmerge updated", v, p1, p2, p, cg, cp, T[v][p].nodes(), T[v][p].edges(), get_cost(
                                T[v][p], G), len(Q)
                        if len(p) == len(P) and cg < min_cost:
                            min_cost = cg
                        # print "Min cost updated by merge ",min_cost
                else:
                    # if mflag==1:
                    T[v][p] = g
                    heappush(Q, (cg, v, p))
                    if len(p) > merge_cov:
                        merge_cov = len(p)
                        if verbose:
                            print "merge length increased to ", len(p)
                    if len(p) == len(P):
                        if verbose:
                            print "\nmerge created new query", v, p, cg, T[v][p].nodes(), T[v][p].edges(), get_cost(
                                T[v][p], G), len(Q)
                    if len(p) == len(P) and cg < min_cost:
                        min_cost = cg
                    # print "Min cost created by merge ",min_cost
                    if verbose:
                        print "\nmerge created new query", v, p, cg, T[v][p].nodes(), T[v][p].edges(), get_cost(T[v][p],
                                                                                                                G), len(
                            Q)
                        print "v p1", v, p1, T[v][p1].nodes(), T[v][p1].edges(), get_cost(T[v][p1], G), len(Q)
                        print "v p2", v, p2, T[v][p2].nodes(), T[v][p2].edges(), get_cost(T[v][p2], G), len(Q)
    # print "\n\nGST Set before returning ",GST_set
    return GST_set

# %%
def check_history(pop_hist, v, p):
    if v in pop_hist:
        if p in pop_hist[v]:
            if verbose:
                print "\nsame item popped"
            return 0
    return 1

# %%
def grow_graph(g1, v, u):
    g = nx.Graph()
    for n in g1.nodes():
        g.add_node(n)
    for (n1, n2) in g1.edges():
        g.add_edge(n1, n2)
    # flag=0
    if u not in g.nodes():
        g.add_node(u)
        g.add_edge(v, u)  # to keep it a tree #access weight from G if needed
    # flag=1

    return g  # ,flag

# %%
def update_queue(Q, cg, u, p):
    for i in range(0, len(Q)):
        if Q[i][1] == u and Q[i][2] == p:
            # if verbose:
            # print "i th ",i,Q[i]
            Q[i] = (cg, u, p)
            heapify(Q)
            break
    return Q

# %%
def merge_graph(g1, g2):
    g = nx.Graph()
    for n in g1.nodes():
        g.add_node(n)
    for (n1, n2) in g1.edges():
        g.add_edge(n1, n2)
    # flag=0
    for n in g2.nodes():
        if n not in g.nodes():
            g.add_node(n)
        # flag=1
    for (n1, n2) in g2.edges():
        if (n1, n2) not in g.edges() and (n2, n1) not in g.edges():
            g.add_edge(n1, n2)
        # flag=1
    return g

# %%
def save_GST(GST_set, v, g1, corner, G):
    g = nx.Graph()
    edge_added = 0
    if chain_join_flag == 1:
        for n in g1.nodes():
            g.add_node(n)
            nn = n.split(':')
            if nn[1] == 'Predicate' and n in corner:  # Add neighbour entities from SPO which are not corner stones
                for nb in G.neighbors(n):
                    data = G.get_edge_data(n, nb)
                    if nb.split(':')[1] == 'Entity' and nb not in g1.neighbors(n) and nb not in corner and data[
                        'etype'] == 'Triple':
                        g.add_node(nb)
                        g.add_edge(n, nb)
                        edge_added += 1

    for (n1, n2) in g1.edges():
        g.add_edge(n1, n2)

    pot_ans_flag = 0
    for n in g.nodes():
        nn = n.split(':')
        if nn[1] == 'Entity' and n not in corner:  # At least one non-cornerstone entity node
            pot_ans_flag = 1

    flag = 1
    for (v2, g2) in GST_set:
        if set(g.edges()) == set(g2.edges()):
            # if g==g2:
            flag = 0
            break

    # print "Cost while saving ",get_cost(g,G),flag,pot_ans_flag,edge_added,len(GST_set)
    # for (n1,n2) in g.edges():
    # data=G.get_edge_data(n1,n2)
    # print "Saved Tree edge ",n1,n2,data['weight'],data['wlist'],data['etype']
    if flag == 1 and pot_ans_flag == 1:
        GST_set.append((v, g))

    return GST_set, flag, pot_ans_flag

# %%
GST_set = get_GST(Q, T, P, G, no_GST, corner, verbose)

# %%
GST_set
# Out:
# [(u'born in:Predicate:1', <networkx.classes.graph.Graph at 0x1ec4d84d0>),
#  (u'apple co-founder jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1151af990>),
#  (u'born in:Predicate:2', <networkx.classes.graph.Graph at 0x1ec574110>),
#  (u'1931:Entity', <networkx.classes.graph.Graph at 0x1ec6383d0>),
#  (u'born in:Predicate:3', <networkx.classes.graph.Graph at 0x1ec638210>),
#  (u'august 1995:Entity', <networkx.classes.graph.Graph at 0x1ec6386d0>),
#  (u'born in:Predicate:4', <networkx.classes.graph.Graph at 0x1ec638790>),
#  (u'born in:Predicate:5', <networkx.classes.graph.Graph at 0x1ec638a50>),
#  (u'1998:Entity', <networkx.classes.graph.Graph at 0x1ec638bd0>),
#  (u'born in:Predicate:6', <networkx.classes.graph.Graph at 0x1ec638a90>),
#  (u'born in:Predicate:7', <networkx.classes.graph.Graph at 0x1ec638d50>),
#  (u'1955:Entity', <networkx.classes.graph.Graph at 0x1ec638f50>),
#  (u'born in:Predicate:8', <networkx.classes.graph.Graph at 0x1ec638910>),
#  (u'born into:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644250>),
#  (u'adoptive families steven paul jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644550>),
#  (u'born on:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644590>),
#  (u'5:00 am , february 24 , 2020 steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644810>),
#  (u'born on:Predicate:10', <networkx.classes.graph.Graph at 0x1ec644950>),
#  (u'24 february 1955:Entity', <networkx.classes.graph.Graph at 0x1ec644050>),
#  (u'born on:Predicate:2', <networkx.classes.graph.Graph at 0x1ec638e10>),
#  (u'born on:Predicate:3', <networkx.classes.graph.Graph at 0x1ec644c10>),
#  (u'born on:Predicate:4', <networkx.classes.graph.Graph at 0x1ec644c50>),
#  (u'2 1.88 m mini bio 1 steven paul jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638090>),
#  (u'born on:Predicate:5', <networkx.classes.graph.Graph at 0x1ec644690>),
#  (u'born on:Predicate:6', <networkx.classes.graph.Graph at 0x1ec644510>),
#  (u'born on:Predicate:7', <networkx.classes.graph.Graph at 0x1ec644bd0>),
#  (u'apple computer:Entity', <networkx.classes.graph.Graph at 0x1ec545090>),
#  (u'born on:Predicate:8', <networkx.classes.graph.Graph at 0x1ec6a63d0>),
#  (u'17 may 1978:Entity', <networkx.classes.graph.Graph at 0x1ec6a65d0>),
#  (u'born on:Predicate:9', <networkx.classes.graph.Graph at 0x1ec6a6610>),
#  (u'born out:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6710>),
#  (u'born:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6990>),
#  (u'born:Predicate:2', <networkx.classes.graph.Graph at 0x1ec6a6950>),
#  (u'adoption jobs:Entity', <networkx.classes.graph.Graph at 0x252ab8a10>),
#  (u'born:Predicate:4', <networkx.classes.graph.Graph at 0x252ab8a50>),
#  (u'born:Predicate:5', <networkx.classes.graph.Graph at 0x252aa6d10>),
#  (u'born:Predicate:6', <networkx.classes.graph.Graph at 0x252aa6c90>),
#  (u'born:Predicate:7', <networkx.classes.graph.Graph at 0x252b27310>),
#  (u'born:Predicate:8', <networkx.classes.graph.Graph at 0x1ec644350>),
#  (u'born:Predicate:9', <networkx.classes.graph.Graph at 0x252b27510>),
#  (u'adoptive father:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f190>),
#  (u'adoptive parents in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f4d0>),
#  (u'baig:Entity', <networkx.classes.graph.Graph at 0x252c1f550>),
#  (u'abdulfattah:Entity', <networkx.classes.graph.Graph at 0x1ec638510>),
#  (u'biological father:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec55bc10>),
#  (u'biological father:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252aa68d0>),
#  (u'biological mother:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f410>),
#  (u'birth after:Predicate:1', <networkx.classes.graph.Graph at 0x1ec574610>),
#  (u'birth family during:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252b27f10>),
#  (u'birth mother out:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1fa50>),
#  (u'brennan:Entity', <networkx.classes.graph.Graph at 0x252c1fbd0>),
#  (u'cupertino:Entity', <networkx.classes.graph.Graph at 0x252c1fc10>),
#  (u'edward c. steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8910>),
#  (u'february 24 , 1955:Entity', <networkx.classes.graph.Graph at 0x252bd8850>),
#  (u'joanne schieble simpson:Entity',
#   <networkx.classes.graph.Graph at 0x252cbcf10>),
#  (u'joanne schieble:Entity', <networkx.classes.graph.Graph at 0x1ec55be90>),
#  (u'2011:Entity', <networkx.classes.graph.Graph at 0x252d2de90>),
#  (u'brennan-jobs by:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252d42c50>),
#  (u'apple co-founder steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec55bfd0>),
#  (u'death in:Predicate:1', <networkx.classes.graph.Graph at 0x252db2090>),
#  (u'find:Predicate:1', <networkx.classes.graph.Graph at 0x252db26d0>),
#  (u'jobs as:Predicate:1', <networkx.classes.graph.Graph at 0x252db2a90>),
#  (u'jobs as:Predicate:2', <networkx.classes.graph.Graph at 0x252db2c10>),
#  (u'jobs as:Predicate:3', <networkx.classes.graph.Graph at 0x252db2d90>),
#  (u'graphisoft park:Entity', <networkx.classes.graph.Graph at 0x1ec5456d0>),
#  (u'jobs at:Predicate:1', <networkx.classes.graph.Graph at 0x252db2dd0>),
#  (u'jobs because:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f090>),
#  (u'jobs by:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f1d0>),
#  (u'jobs from:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f3d0>),
#  (u'jobs in:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f490>),
#  (u'jobs in:Predicate:2', <networkx.classes.graph.Graph at 0x252a4f6d0>),
#  (u'jobs in:Predicate:3', <networkx.classes.graph.Graph at 0x252a4f650>),
#  (u'1954:Entity', <networkx.classes.graph.Graph at 0x252a4f950>),
#  (u'fell in:Predicate:1', <networkx.classes.graph.Graph at 0x252a4fa50>),
#  (u'jobs in:Predicate:4', <networkx.classes.graph.Graph at 0x252a4fad0>),
#  (u'jobs in:Predicate:5', <networkx.classes.graph.Graph at 0x252a4fc10>),
#  (u'jobs in:Predicate:6', <networkx.classes.graph.Graph at 0x252a4fdd0>),
#  (u'jobs in:Predicate:7', <networkx.classes.graph.Graph at 0x252ce3110>),
#  (u'jobs of:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644850>),
#  (u'jobs on:Predicate:1', <networkx.classes.graph.Graph at 0x252e84050>),
#  (u'jobs on:Predicate:2', <networkx.classes.graph.Graph at 0x252e84190>),
#  (u'jobs on:Predicate:3', <networkx.classes.graph.Graph at 0x252e841d0>),
#  (u'jobs outside:Predicate:1', <networkx.classes.graph.Graph at 0x252e844d0>),
#  (u'1985 jobs:Entity', <networkx.classes.graph.Graph at 0x252ab8b90>),
#  (u'announcement of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f18910>),
#  (u'became:Predicate:1', <networkx.classes.graph.Graph at 0x252f694d0>),
#  (u'became with:Predicate:1', <networkx.classes.graph.Graph at 0x252a4fa10>),
#  (u'became:Predicate:2', <networkx.classes.graph.Graph at 0x252f69550>),
#  (u'became:Predicate:3', <networkx.classes.graph.Graph at 0x252a4fe50>),
#  (u'brought:Predicate:2', <networkx.classes.graph.Graph at 0x252f69750>),
#  (u'brought:Predicate:1', <networkx.classes.graph.Graph at 0x252f69890>),
#  (u'co-found:Predicate:1', <networkx.classes.graph.Graph at 0x252f69190>),
#  (u'co-founded:Predicate:1', <networkx.classes.graph.Graph at 0x252db2850>),
#  (u'apple computers:Entity', <networkx.classes.graph.Graph at 0x252f69bd0>),
#  (u'apple computer inc:Entity', <networkx.classes.graph.Graph at 0x1ec545c10>),
#  (u'found:Predicate:1', <networkx.classes.graph.Graph at 0x252f69f90>),
#  (u'fame:Entity', <networkx.classes.graph.Graph at 0x252f69dd0>),
#  (u'founded for:Predicate:1', <networkx.classes.graph.Graph at 0x2530520d0>),
#  (u'igod:Predicate:1', <networkx.classes.graph.Graph at 0x253052190>),
#  (u'important part of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052290>),
#  (u'big part of:Predicate:1', <networkx.classes.graph.Graph at 0x253052510>),
#  (u'big believer in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052650>),
#  (u'important persons in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052790>),
#  (u'inventor:Type', <networkx.classes.graph.Graph at 0x252bd83d0>),
#  (u'jobs powerless within:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2530c2d90>),
#  (u'jobs that:Predicate:1', <networkx.classes.graph.Graph at 0x2530c2e50>),
#  (u'jobs that:Predicate:2', <networkx.classes.graph.Graph at 0x2530c2ed0>),
#  (u'jobs through:Predicate:1', <networkx.classes.graph.Graph at 0x252d2d090>),
#  (u'jobs until:Predicate:1', <networkx.classes.graph.Graph at 0x252e840d0>),
#  (u'jobs while:Predicate:1', <networkx.classes.graph.Graph at 0x2531193d0>),
#  (u'jobs while:Predicate:2', <networkx.classes.graph.Graph at 0x253119550>),
#  (u'jobs while:Predicate:3', <networkx.classes.graph.Graph at 0x253119490>),
#  (u'jobs while:Predicate:4', <networkx.classes.graph.Graph at 0x253119690>),
#  (u'enrolled at:Predicate:1', <networkx.classes.graph.Graph at 0x253192450>),
#  (u'allowed:Predicate:1', <networkx.classes.graph.Graph at 0x253192690>),
#  (u'allowed:Predicate:2', <networkx.classes.graph.Graph at 0x253192990>),
#  (u'interested:Predicate:1', <networkx.classes.graph.Graph at 0x2531c7610>),
#  (u'adopted by:Predicate:1', <networkx.classes.graph.Graph at 0x253192110>),
#  (u'adopted by:Predicate:2', <networkx.classes.graph.Graph at 0x2530c2e90>),
#  (u'adopted by:Predicate:3', <networkx.classes.graph.Graph at 0x2531c7f50>),
#  (u'adopted:Predicate:1', <networkx.classes.graph.Graph at 0x252ab8350>),
#  (u'adopted:Predicate:2', <networkx.classes.graph.Graph at 0x252cbce50>),
#  (u'cared about:Predicate:1', <networkx.classes.graph.Graph at 0x25325a150>),
#  (u'child:Entity', <networkx.classes.graph.Graph at 0x25325a290>),
#  (u'coddled:Predicate:1', <networkx.classes.graph.Graph at 0x25325a350>),
#  (u'german-swiss joanne carol schieble:Entity',
#   <networkx.classes.graph.Graph at 0x25325a3d0>),
#  (u'guest:Type', <networkx.classes.graph.Graph at 0x25325a410>),
#  (u'british-born industrial designer:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6dd0>),
#  (u'help of:Predicate:1', <networkx.classes.graph.Graph at 0x25325a4d0>),
#  (u'is that:Predicate:1', <networkx.classes.graph.Graph at 0x252c1f6d0>),
#  (u'jobs:Entity', <networkx.classes.graph.Graph at 0x252bd8390>),
#  (u'disclosed about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6f90>),
#  (u'lisa:Entity', <networkx.classes.graph.Graph at 0x25325af90>),
#  (u'lost interview schieble:Entity',
#   <networkx.classes.graph.Graph at 0x2532c6210>),
#  (u'1983:Entity', <networkx.classes.graph.Graph at 0x2532c63d0>),
#  (u'lost steve jobs speech from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2532c6610>),
#  (u'consciousness the day before:Entity',
#   <networkx.classes.graph.Graph at 0x252ba0cd0>),
#  (u'death jobs:Entity', <networkx.classes.graph.Graph at 0x252aa6490>),
#  (u'described in:Predicate:1', <networkx.classes.graph.Graph at 0x2532c6e50>),
#  (u'described:Predicate:1', <networkx.classes.graph.Graph at 0x253338050>),
#  (u'described:Predicate:2', <networkx.classes.graph.Graph at 0x2533380d0>),
#  (u'died at:Predicate:1', <networkx.classes.graph.Graph at 0x252d42f50>),
#  (u'died at:Predicate:2', <networkx.classes.graph.Graph at 0x252db2350>),
#  (u'died at:Predicate:3', <networkx.classes.graph.Graph at 0x252d42e50>),
#  (u'died in:Predicate:1', <networkx.classes.graph.Graph at 0x252e84410>),
#  (u'died of:Predicate:1', <networkx.classes.graph.Graph at 0x252e84550>),
#  (u'died of:Predicate:2', <networkx.classes.graph.Graph at 0x253338510>),
#  (u'died with:Predicate:1', <networkx.classes.graph.Graph at 0x253338590>),
#  (u'died:Predicate:1', <networkx.classes.graph.Graph at 0x2533385d0>),
#  (u'january 2001:Entity', <networkx.classes.graph.Graph at 0x253338790>),
#  (u'last words jobs:Entity', <networkx.classes.graph.Graph at 0x253338950>),
#  (u'lost:Predicate:1', <networkx.classes.graph.Graph at 0x2533387d0>),
#  (u'made at:Predicate:1', <networkx.classes.graph.Graph at 0x253338d10>),
#  (u'married because:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec574310>),
#  (u'married in:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9790>),
#  (u'1991:Entity', <networkx.classes.graph.Graph at 0x2533f98d0>),
#  (u'married in:Predicate:2', <networkx.classes.graph.Graph at 0x2533f9650>),
#  (u'married in:Predicate:3', <networkx.classes.graph.Graph at 0x2533f9a50>),
#  (u'laurene powell:Entity', <networkx.classes.graph.Graph at 0x2533f9b90>),
#  (u'march 18 , 1991:Entity', <networkx.classes.graph.Graph at 0x2533f9910>),
#  (u'married on:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9c10>),
#  (u'married with:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9d90>),
#  (u'liberal arts:Entity', <networkx.classes.graph.Graph at 0x2533f9c90>),
#  (u'married with:Predicate:2', <networkx.classes.graph.Graph at 0x2533f9ed0>),
#  (u'married:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9f50>),
#  (u'married:Predicate:2', <networkx.classes.graph.Graph at 0x2534a1110>),
#  (u'married:Predicate:3', <networkx.classes.graph.Graph at 0x2534a1190>),
#  (u'married:Predicate:4', <networkx.classes.graph.Graph at 0x1ec644a10>),
#  (u'four times:Entity', <networkx.classes.graph.Graph at 0x2534a12d0>),
#  (u'married:Predicate:5', <networkx.classes.graph.Graph at 0x2534a1310>),
#  (u'biological parents:Entity', <networkx.classes.graph.Graph at 0x2534a1410>),
#  (u'married:Predicate:6', <networkx.classes.graph.Graph at 0x252aa6850>),
#  (u'clara hagopian:Entity', <networkx.classes.graph.Graph at 0x2531c7350>),
#  (u'married:Predicate:7', <networkx.classes.graph.Graph at 0x252b27b90>),
#  (u'married:Predicate:8', <networkx.classes.graph.Graph at 0x2534a1710>),
#  (u'mature:Type', <networkx.classes.graph.Graph at 0x2534a1750>),
#  (u'ms schieble:Entity', <networkx.classes.graph.Graph at 0x252cbcc10>),
#  (u'interim chief the new york times:Entity',
#   <networkx.classes.graph.Graph at 0x2534a1ad0>),
#  (u'names jobs as:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f050>),
#  (u'odd individual:Type', <networkx.classes.graph.Graph at 0x2534a1c50>),
#  (u'offered:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1d90>),
#  (u'opens:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1e10>),
#  (u'opens at:Predicate:1', <networkx.classes.graph.Graph at 0x25350c190>),
#  (u'opposed:Predicate:1', <networkx.classes.graph.Graph at 0x252ce3b90>),
#  (u'opposed:Predicate:2', <networkx.classes.graph.Graph at 0x25350c390>),
#  (u'palo alto:Entity', <networkx.classes.graph.Graph at 0x252ba05d0>),
#  (u'part of:Predicate:1', <networkx.classes.graph.Graph at 0x25350c610>),
#  (u'paul jobs:Entity', <networkx.classes.graph.Graph at 0x25350c890>),
#  (u'coast guard mechanic:Type', <networkx.classes.graph.Graph at 0x25350c990>),
#  (u'paul reinhold jobs:Entity', <networkx.classes.graph.Graph at 0x25350c8d0>),
#  (u'coast guard veteran:Type', <networkx.classes.graph.Graph at 0x25350ca10>),
#  (u'person:Entity', <networkx.classes.graph.Graph at 0x25350cb10>),
#  (u'pixar animation studios:Entity',
#   <networkx.classes.graph.Graph at 0x25350ce10>),
#  (u'profitability jobs on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253573450>),
#  (u'profitability jobs on:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253573550>),
#  (u'profitability jobs on:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253573690>),
#  (u'realize that:Predicate:1', <networkx.classes.graph.Graph at 0x252b27dd0>),
#  (u'3 p.m. on october 5 , 2011:Entity',
#   <networkx.classes.graph.Graph at 0x252499ed0>),
#  (u'home around:Predicate:1', <networkx.classes.graph.Graph at 0x2535de390>),
#  (u'home in:Predicate:1', <networkx.classes.graph.Graph at 0x2535de650>),
#  (u'home of:Predicate:1', <networkx.classes.graph.Graph at 0x2535de6d0>),
#  (u'los altos:Entity', <networkx.classes.graph.Graph at 0x2535de7d0>),
#  (u'mountain view home as:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2535de790>),
#  (u'respiratory arrest:Entity', <networkx.classes.graph.Graph at 0x25325a190>),
#  (u'resulted in:Predicate:1', <networkx.classes.graph.Graph at 0x2535dea90>),
#  (u'run:Predicate:1', <networkx.classes.graph.Graph at 0x2535def10>),
#  (u'run:Predicate:2', <networkx.classes.graph.Graph at 0x2535defd0>),
#  (u'san francisco bay area portal list:Entity',
#   <networkx.classes.graph.Graph at 0x2535dee50>),
#  (u'saved:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2210>),
#  (u'says from:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2590>),
#  (u'says:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2950>),
#  (u'says:Predicate:2', <networkx.classes.graph.Graph at 0x252c1ff10>),
#  (u'service in:Predicate:1', <networkx.classes.graph.Graph at 0x25371b050>),
#  (u'sister patti jobs:Entity', <networkx.classes.graph.Graph at 0x25371b250>),
#  (u'started:Predicate:4', <networkx.classes.graph.Graph at 0x25371bad0>),
#  (u'states that:Predicate:1', <networkx.classes.graph.Graph at 0x25371bed0>),
#  (u'steve jobs aug 21 , 2019 apr 27 , 2017 steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x25371be90>),
#  (u'great:Entity', <networkx.classes.graph.Graph at 0x252b27150>),
#  (u'steve jobs so:Predicate:1', <networkx.classes.graph.Graph at 0x253701690>),
#  (u'steve jobs story:Entity', <networkx.classes.graph.Graph at 0x252ab88d0>),
#  (u'india:Entity', <networkx.classes.graph.Graph at 0x2537019d0>),
#  (u'steve jobs the times of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701a90>),
#  (u'steve jobs theatre:Entity', <networkx.classes.graph.Graph at 0x2536a2110>),
#  (u'steve jobs media:Entity', <networkx.classes.graph.Graph at 0x252aa62d0>),
#  (u'steve jobs timeline of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701dd0>),
#  (u'steve jobs will:Entity', <networkx.classes.graph.Graph at 0x253701f10>),
#  (u'diagnosed with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2538caf10>),
#  (u'introduced:Predicate:1', <networkx.classes.graph.Graph at 0x2531c7cd0>),
#  (u'icloud:Entity', <networkx.classes.graph.Graph at 0x2538ca4d0>),
#  (u'introduced:Predicate:10', <networkx.classes.graph.Graph at 0x2539579d0>),
#  (u'introduced:Predicate:2', <networkx.classes.graph.Graph at 0x253957bd0>),
#  (u'introduced:Predicate:4', <networkx.classes.graph.Graph at 0x253957e10>),
#  (u'introduced:Predicate:5', <networkx.classes.graph.Graph at 0x253957ed0>),
#  (u'introduced:Predicate:6', <networkx.classes.graph.Graph at 0x253957e90>),
#  (u'introduced:Predicate:7', <networkx.classes.graph.Graph at 0x2531925d0>),
#  (u'introduced:Predicate:8', <networkx.classes.graph.Graph at 0x253992110>),
#  (u'introduced:Predicate:9', <networkx.classes.graph.Graph at 0x252ab8690>),
#  (u'iphone:Entity', <networkx.classes.graph.Graph at 0x253802090>),
#  (u'jobs steve jobs:Entity', <networkx.classes.graph.Graph at 0x252bd8290>),
#  (u'after jobs:Entity', <networkx.classes.graph.Graph at 0x25325a7d0>),
#  (u'death:Predicate:1', <networkx.classes.graph.Graph at 0x253992590>),
#  (u'iger:Entity', <networkx.classes.graph.Graph at 0x253992650>),
#  (u'23-year-old students:Entity',
#   <networkx.classes.graph.Graph at 0x253992ad0>),
#  (u'met as:Predicate:1', <networkx.classes.graph.Graph at 0x253992b10>),
#  (u'met:Predicate:1', <networkx.classes.graph.Graph at 0x253992bd0>),
#  (u'criticized:Predicate:1', <networkx.classes.graph.Graph at 0x25350c3d0>),
#  (u'dell:Entity', <networkx.classes.graph.Graph at 0x253992c90>),
#  (u'first jobs:Entity', <networkx.classes.graph.Graph at 0x25325aa50>),
#  (u'met:Predicate:3', <networkx.classes.graph.Graph at 0x252b27390>),
#  (u'disney steve jobs:Entity', <networkx.classes.graph.Graph at 0x252ab8e90>),
#  (u'met:Predicate:4', <networkx.classes.graph.Graph at 0x253992ed0>),
#  (u'known as:Predicate:1', <networkx.classes.graph.Graph at 0x253859ed0>),
#  (u'one:Entity', <networkx.classes.graph.Graph at 0x25350ce50>),
#  (u'pancreatic cancer:Entity', <networkx.classes.graph.Graph at 0x253a13510>),
#  (u'fund:Predicate:1', <networkx.classes.graph.Graph at 0x252aa6690>),
#  (u'pixar:Entity', <networkx.classes.graph.Graph at 0x253a13750>),
#  (u'new questions:Entity', <networkx.classes.graph.Graph at 0x253a13a90>),
#  (u'raised about:Predicate:1', <networkx.classes.graph.Graph at 0x253a13990>),
#  (u'apple jobs:Entity', <networkx.classes.graph.Graph at 0x1ec638250>),
#  (u'raised by:Predicate:1', <networkx.classes.graph.Graph at 0x253a13c50>),
#  (u'raised:Predicate:1', <networkx.classes.graph.Graph at 0x253a13d50>),
#  (u'mother:Entity', <networkx.classes.graph.Graph at 0x252aa6b50>),
#  (u'raised:Predicate:2', <networkx.classes.graph.Graph at 0x2533f9550>),
#  (u'held:Predicate:1', <networkx.classes.graph.Graph at 0x253a8c750>),
#  (u'oct. 16:Entity', <networkx.classes.graph.Graph at 0x253a8c710>),
#  (u'private steve jobs memorial:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8f90>),
#  (u"'d:Predicate:1", <networkx.classes.graph.Graph at 0x253b16dd0>),
#  (u'accepted:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1ed0>),
#  (u'advice:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c790>),
#  (u'agree:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c850>),
#  (u'announced that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2538afd10>),
#  (u'announced:Predicate:1', <networkx.classes.graph.Graph at 0x253b5ca90>),
#  (u'announced:Predicate:2', <networkx.classes.graph.Graph at 0x253b5cad0>),
#  (u'announced:Predicate:3', <networkx.classes.graph.Graph at 0x253b5cb90>),
#  (u'announces:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2e10>),
#  (u'become:Predicate:1', <networkx.classes.graph.Graph at 0x252f69650>),
#  (u'become:Predicate:2', <networkx.classes.graph.Graph at 0x252f695d0>),
#  (u'become:Predicate:3', <networkx.classes.graph.Graph at 0x253b5cf90>),
#  (u'believe in:Predicate:1', <networkx.classes.graph.Graph at 0x253119b50>),
#  (u'bought:Predicate:1', <networkx.classes.graph.Graph at 0x252e845d0>),
#  (u'built:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1590>),
#  (u'buried:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1650>),
#  (u'buys:Predicate:1', <networkx.classes.graph.Graph at 0x253ba12d0>),
#  (u'called:Predicate:1', <networkx.classes.graph.Graph at 0x2532c6f90>),
#  (u'called:Predicate:2', <networkx.classes.graph.Graph at 0x253ba1790>),
#  (u'called:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1910>),
#  (u'attitude:Entity', <networkx.classes.graph.Graph at 0x2530c2750>),
#  (u'came from:Predicate:1', <networkx.classes.graph.Graph at 0x2530c2790>),
#  (u'came in:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1a90>),
#  (u'came:Predicate:1', <networkx.classes.graph.Graph at 0x252f69a50>),
#  (u'came:Predicate:2', <networkx.classes.graph.Graph at 0x253ba17d0>),
#  (u'came:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1d90>),
#  (u'caused:Predicate:1', <networkx.classes.graph.Graph at 0x2535dec10>),
#  (u'close encounters with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec4d8d10>),
#  (u'collect:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1f50>),
#  (u'compared:Predicate:1', <networkx.classes.graph.Graph at 0x253119390>),
#  (u'compared:Predicate:2', <networkx.classes.graph.Graph at 0x253bc2210>),
#  (u'computer:Entity', <networkx.classes.graph.Graph at 0x253bc22d0>),
#  (u'convinced that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253573cd0>),
#  (u'convinced:Predicate:1', <networkx.classes.graph.Graph at 0x253ba11d0>),
#  (u'decided:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2dd0>),
#  (u'decided:Predicate:2', <networkx.classes.graph.Graph at 0x253b16e90>),
#  (u'aqua:Entity', <networkx.classes.graph.Graph at 0x253bc2650>),
#  (u'demoed:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2710>),
#  (u'designed after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69ed0>),
#  (u'designed:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6a50>),
#  (u'desktop video:Entity', <networkx.classes.graph.Graph at 0x253bc28d0>),
#  (u'discovered:Predicate:1', <networkx.classes.graph.Graph at 0x252f69c90>),
#  (u'engaging with:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a60d0>),
#  (u'everyone:Entity', <networkx.classes.graph.Graph at 0x253bc2a10>),
#  (u'ex-girlfriend from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f790>),
#  (u'a memoir of:Predicate:1', <networkx.classes.graph.Graph at 0x252d42b50>),
#  (u'ex-girlfriend pens memoir on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2b50>),
#  (u'exacted:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2c10>),
#  (u'biography:Entity', <networkx.classes.graph.Graph at 0x2537b0dd0>),
#  (u'explained in:Predicate:1', <networkx.classes.graph.Graph at 0x252ce3690>),
#  (u'explained that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2cd0>),
#  (u'explained:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2c50>),
#  (u'feeling:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2c10>),
#  (u'felt:Predicate:1', <networkx.classes.graph.Graph at 0x253c1f090>),
#  (u'fired from:Predicate:1', <networkx.classes.graph.Graph at 0x252e84650>),
#  (u'formed:Predicate:1', <networkx.classes.graph.Graph at 0x252f69cd0>),
#  (u'half staff for:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ad89d0>),
#  (u'hands dirty in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1f350>),
#  (u'happened after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db2990>),
#  (u'hardest-working in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1fdd0>),
#  (u'helped:Predicate:1', <networkx.classes.graph.Graph at 0x25325a590>),
#  (u'high school chrisann brennan:Entity',
#   <networkx.classes.graph.Graph at 0x253c1f710>),
#  (u'first:Entity', <networkx.classes.graph.Graph at 0x252aa6b90>),
#  (u'hired:Predicate:1', <networkx.classes.graph.Graph at 0x253992fd0>),
#  (u'historic:Predicate:1', <networkx.classes.graph.Graph at 0x253aea050>),
#  (u'immigration policies:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701e10>),
#  (u'inaugurated:Predicate:1', <networkx.classes.graph.Graph at 0x253c1fd10>),
#  (u'insistence that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1fe10>),
#  (u'interview with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1fe50>),
#  (u'introduces:Predicate:1', <networkx.classes.graph.Graph at 0x2531c7e50>),
#  (u'introducing:Predicate:1', <networkx.classes.graph.Graph at 0x25350c450>),
#  (u'invented:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b090>),
#  (u'launch:Entity', <networkx.classes.graph.Graph at 0x253c7b1d0>),
#  (u'learn from:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b110>),
#  (u'06 oct 2011:Entity', <networkx.classes.graph.Graph at 0x252c1fe50>),
#  (u'legacy:Predicate:1', <networkx.classes.graph.Graph at 0x252310c10>),
#  (u'life with:Predicate:2', <networkx.classes.graph.Graph at 0x252f18e90>),
#  (u'listed as:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b490>),
#  (u'looked for:Predicate:1', <networkx.classes.graph.Graph at 0x253c1f150>),
#  (u'loved:Predicate:1', <networkx.classes.graph.Graph at 0x25325a1d0>),
#  (u'mac os 9:Entity', <networkx.classes.graph.Graph at 0x253b5cb50>),
#  (u'ipod:Entity', <networkx.classes.graph.Graph at 0x253b5cb10>),
#  (u'made:Predicate:4', <networkx.classes.graph.Graph at 0x252aa64d0>),
#  (u'mistake of:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b890>),
#  (u'name along:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1c10>),
#  ('ne:Type', <networkx.classes.graph.Graph at 0x253c7ba50>),
#  (u'negotiated:Predicate:1', <networkx.classes.graph.Graph at 0x253b161d0>),
#  (u'negotiated:Predicate:2', <networkx.classes.graph.Graph at 0x253c7bc10>),
#  (u'nextcomputer:Entity', <networkx.classes.graph.Graph at 0x253c7bc90>),
#  (u'official memorial page for:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69450>),
#  (u'oversaw:Predicate:1', <networkx.classes.graph.Graph at 0x253992310>),
#  (u'oversaw:Predicate:2', <networkx.classes.graph.Graph at 0x253c7be10>),
#  (u'own money in:Predicate:1', <networkx.classes.graph.Graph at 0x253802e10>),
#  (u'passions as:Predicate:1', <networkx.classes.graph.Graph at 0x253c7be90>),
#  (u'pcs:Entity', <networkx.classes.graph.Graph at 0x253cd0090>),
#  (u'perfectionist demands on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252cbc1d0>),
#  (u'now:Entity', <networkx.classes.graph.Graph at 0x253cd0250>),
#  (u'private spirituality:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cd0290>),
#  (u'parents:Entity', <networkx.classes.graph.Graph at 0x1ec638b10>),
#  (u'put:Predicate:1', <networkx.classes.graph.Graph at 0x252f69950>),
#  (u'put:Predicate:2', <networkx.classes.graph.Graph at 0x2531c7390>),
#  (u'put:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1e90>),
#  (u'great job:Entity', <networkx.classes.graph.Graph at 0x2537016d0>),
#  (u'raising:Predicate:1', <networkx.classes.graph.Graph at 0x253701610>),
#  (u'rare pancreatic cancer:Entity',
#   <networkx.classes.graph.Graph at 0x253cd05d0>),
#  (u'realized that:Predicate:1', <networkx.classes.graph.Graph at 0x253573d50>),
#  (u'realizing:Predicate:1', <networkx.classes.graph.Graph at 0x253573e10>),
#  (u'liver transplant:Entity', <networkx.classes.graph.Graph at 0x253701510>),
#  (u'recovering after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cd0810>),
#  (u'refused:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c510>),
#  (u'ceo:Entity', <networkx.classes.graph.Graph at 0x253c7b650>),
#  (u'remained:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b790>),
#  (u'resigned in:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2f90>),
#  (u'gap:Entity', <networkx.classes.graph.Graph at 0x253cd0d90>),
#  (u'resigns from:Predicate:1', <networkx.classes.graph.Graph at 0x253cd0e90>),
#  (u'returned without:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253a8cb90>),
#  (u'returned:Predicate:1', <networkx.classes.graph.Graph at 0x252cbc6d0>),
#  (u'apple stock options scandal:Entity',
#   <networkx.classes.graph.Graph at 0x252f18b10>),
#  (u'role in:Predicate:1', <networkx.classes.graph.Graph at 0x253cf6150>),
#  (u'role in:Predicate:2', <networkx.classes.graph.Graph at 0x253cf6250>),
#  (u'said that:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2bd0>),
#  (u'said:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2dd0>),
#  (u'ms simpson:Entity', <networkx.classes.graph.Graph at 0x2534a1a10>),
#  (u'said:Predicate:2', <networkx.classes.graph.Graph at 0x252cbce10>),
#  (u'say about:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1150>),
#  (u'september 1985:Entity', <networkx.classes.graph.Graph at 0x253cf6790>),
#  (u'speculated that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f18d90>),
#  (u'staff in:Predicate:1', <networkx.classes.graph.Graph at 0x253cf6890>),
#  (u'started:Predicate:1', <networkx.classes.graph.Graph at 0x25371be50>),
#  (u'started:Predicate:5', <networkx.classes.graph.Graph at 0x25371bd90>),
#  (u'started:Predicate:7', <networkx.classes.graph.Graph at 0x25371bd10>),
#  (u'started:Predicate:9', <networkx.classes.graph.Graph at 0x25371bc90>),
#  (u'steve jobs:Entity', <networkx.classes.graph.Graph at 0x253cf6b50>),
#  (u'steve:Entity', <networkx.classes.graph.Graph at 0x2537b0410>),
#  (u'steven p. jobs trust:Entity',
#   <networkx.classes.graph.Graph at 0x253e1b110>),
#  (u'named:Predicate:1', <networkx.classes.graph.Graph at 0x25350c850>),
#  (u'subsequent years jobs:Entity',
#   <networkx.classes.graph.Graph at 0x253cd0e10>),
#  (u'take:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1a10>),
#  (u'taking:Predicate:1', <networkx.classes.graph.Graph at 0x2530c2650>),
#  (u'talking about:Predicate:1', <networkx.classes.graph.Graph at 0x253e1b650>),
#  (u'technology:Entity', <networkx.classes.graph.Graph at 0x253e1b690>),
#  (u'tells:Predicate:1', <networkx.classes.graph.Graph at 0x253e1b990>),
#  (u'tensions between:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cf6410>),
#  (u'the next five years:Entity',
#   <networkx.classes.graph.Graph at 0x253e1bb10>),
#  (u'thing about:Predicate:1', <networkx.classes.graph.Graph at 0x252ab8150>),
#  (u'appeared on:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b690>),
#  (u'appeared on:Predicate:2', <networkx.classes.graph.Graph at 0x253992810>),
#  (u'concerns about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253e1bfd0>),
#  (u'course that:Predicate:1', <networkx.classes.graph.Graph at 0x253ea1250>),
#  (u'received:Predicate:1', <networkx.classes.graph.Graph at 0x253ea12d0>),
#  (u'2009 jobs:Entity', <networkx.classes.graph.Graph at 0x25325a950>),
#  (u'stage:Entity', <networkx.classes.graph.Graph at 0x253ea14d0>),
#  (u'taking:Predicate:2', <networkx.classes.graph.Graph at 0x253bc2510>),
#  (u'thinner steve jobs:Entity', <networkx.classes.graph.Graph at 0x253ea1510>),
#  (u'thrown out:Predicate:1', <networkx.classes.graph.Graph at 0x253ea17d0>),
#  (u'today:Entity', <networkx.classes.graph.Graph at 0x253ea1650>),
#  (u'told:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2a90>),
#  (u'told:Predicate:2', <networkx.classes.graph.Graph at 0x253cd0150>),
#  (u'took in:Predicate:1', <networkx.classes.graph.Graph at 0x253cd0490>),
#  (u'took:Predicate:1', <networkx.classes.graph.Graph at 0x25371b510>),
#  (u'took:Predicate:2', <networkx.classes.graph.Graph at 0x253ea1c10>),
#  (u'interest:Entity', <networkx.classes.graph.Graph at 0x253ea1cd0>),
#  (u'took:Predicate:3', <networkx.classes.graph.Graph at 0x253ea1c50>),
#  (u'took:Predicate:4', <networkx.classes.graph.Graph at 0x253ea1e10>),
#  (u'took:Predicate:5', <networkx.classes.graph.Graph at 0x253ea1dd0>),
#  (u'tries:Predicate:1', <networkx.classes.graph.Graph at 0x253701f90>),
#  (u'300 patents:Entity', <networkx.classes.graph.Graph at 0x253f0b210>),
#  (u'underscores:Predicate:1', <networkx.classes.graph.Graph at 0x253f0b2d0>),
#  (u'understood that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2d10>),
#  (u'understood that:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f0b510>),
#  (u'understood:Predicate:1', <networkx.classes.graph.Graph at 0x253f0b610>),
#  (u'rebellious jobs:Entity', <networkx.classes.graph.Graph at 0x252aa67d0>),
#  (u'underwent:Predicate:2', <networkx.classes.graph.Graph at 0x253f0b8d0>),
#  (u'hungary science park:Entity',
#   <networkx.classes.graph.Graph at 0x253119fd0>),
#  (u'steve jobs statue:Entity', <networkx.classes.graph.Graph at 0x252bd8550>),
#  (u'unveiled:Predicate:1', <networkx.classes.graph.Graph at 0x252db2d50>),
#  (u'unveiled:Predicate:2', <networkx.classes.graph.Graph at 0x253f0bd90>),
#  (u'unveiled:Predicate:3', <networkx.classes.graph.Graph at 0x253f0be90>),
#  (u'unveiled:Predicate:4', <networkx.classes.graph.Graph at 0x253f0bf50>),
#  (u'departure:Entity', <networkx.classes.graph.Graph at 0x253f0bfd0>),
#  (u'upcoming:Predicate:1', <networkx.classes.graph.Graph at 0x253f0bc90>),
#  (u'us:Entity', <networkx.classes.graph.Graph at 0x253f76090>),
#  (u'use:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644450>),
#  (u'used:Predicate:1', <networkx.classes.graph.Graph at 0x253f76110>),
#  (u'used:Predicate:2', <networkx.classes.graph.Graph at 0x253f76310>),
#  (u'used:Predicate:3', <networkx.classes.graph.Graph at 0x253f76490>),
#  (u'used:Predicate:4', <networkx.classes.graph.Graph at 0x253f76590>),
#  (u'view of:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6850>),
#  (u'vision of:Predicate:1', <networkx.classes.graph.Graph at 0x252bd8150>),
#  (u'want:Predicate:1', <networkx.classes.graph.Graph at 0x252ab82d0>),
#  (u'want:Predicate:2', <networkx.classes.graph.Graph at 0x253d35fd0>),
#  (u'wanted:Predicate:1', <networkx.classes.graph.Graph at 0x253573110>),
#  (u'wanted:Predicate:2', <networkx.classes.graph.Graph at 0x253f76a10>),
#  (u'wanted:Predicate:3', <networkx.classes.graph.Graph at 0x253f769d0>),
#  (u'wanted:Predicate:4', <networkx.classes.graph.Graph at 0x253f76b90>),
#  (u'biological father steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6590>),
#  (u'steve jobs biological father:Entity',
#   <networkx.classes.graph.Graph at 0x2538af6d0>),
#  (u'1985:Entity', <networkx.classes.graph.Graph at 0x252f18a50>),
#  (u'was in:Predicate:1', <networkx.classes.graph.Graph at 0x253cf6e10>),
#  (u'engineering:Entity', <networkx.classes.graph.Graph at 0x253f76e50>),
#  (u'was in:Predicate:3', <networkx.classes.graph.Graph at 0x253f76e10>),
#  (u'was on:Predicate:1', <networkx.classes.graph.Graph at 0x253f76ed0>),
#  (u'atari:Entity', <networkx.classes.graph.Graph at 0x253cd0ed0>),
#  (u'video game designer:Type', <networkx.classes.graph.Graph at 0x253ffa110>),
#  (u'was with:Predicate:1', <networkx.classes.graph.Graph at 0x2537b0150>),
#  (u'went:Predicate:2', <networkx.classes.graph.Graph at 0x2537b0bd0>),
#  (u'were among:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c610>),
#  (u'many years later:Entity', <networkx.classes.graph.Graph at 0x253ffa410>),
#  (u'wife laurene:Predicate:1', <networkx.classes.graph.Graph at 0x253ffa350>),
#  (u'laurene:Entity', <networkx.classes.graph.Graph at 0x2533f9bd0>),
#  (u'wife:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9810>),
#  (u'special grammy:Entity', <networkx.classes.graph.Graph at 0x253ffa650>),
#  (u'wins:Predicate:1', <networkx.classes.graph.Graph at 0x253ffa750>),
#  (u'wins:Predicate:2', <networkx.classes.graph.Graph at 0x253ffa890>),
#  (u'woodside mansion:Entity', <networkx.classes.graph.Graph at 0x2532c6810>),
#  (u'worked with:Predicate:1', <networkx.classes.graph.Graph at 0x253ffa8d0>),
#  (u'working:Predicate:1', <networkx.classes.graph.Graph at 0x253ffaa10>),
#  (u'wozniak jobs:Entity', <networkx.classes.graph.Graph at 0x253ffaad0>),
#  (u'writer steve martin:Entity',
#   <networkx.classes.graph.Graph at 0x253ffac10>),
#  (u'steve jobs isaacson:Entity',
#   <networkx.classes.graph.Graph at 0x252aa65d0>),
#  (u'writes that:Predicate:1', <networkx.classes.graph.Graph at 0x253a8c3d0>),
#  (u'writes that:Predicate:2', <networkx.classes.graph.Graph at 0x253ffad50>),
#  (u'wrote of:Predicate:1', <networkx.classes.graph.Graph at 0x252ce3c50>),
#  (u'wrote:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f390>),
#  (u'yesterday:Entity', <networkx.classes.graph.Graph at 0x253ffae90>),
#  (u'grew:Predicate:1', <networkx.classes.graph.Graph at 0x253992390>),
#  (u'young steve jobs:Entity', <networkx.classes.graph.Graph at 0x254049250>),
#  (u'\u2019s:Predicate:1', <networkx.classes.graph.Graph at 0x254049310>)]

# %%
GST_set_list = GST_set
GST_set = set(GST_set)

# %%
GST_set_list
# Out:
# [(u'born in:Predicate:1', <networkx.classes.graph.Graph at 0x1ec4d84d0>),
#  (u'apple co-founder jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1151af990>),
#  (u'born in:Predicate:2', <networkx.classes.graph.Graph at 0x1ec574110>),
#  (u'1931:Entity', <networkx.classes.graph.Graph at 0x1ec6383d0>),
#  (u'born in:Predicate:3', <networkx.classes.graph.Graph at 0x1ec638210>),
#  (u'august 1995:Entity', <networkx.classes.graph.Graph at 0x1ec6386d0>),
#  (u'born in:Predicate:4', <networkx.classes.graph.Graph at 0x1ec638790>),
#  (u'born in:Predicate:5', <networkx.classes.graph.Graph at 0x1ec638a50>),
#  (u'1998:Entity', <networkx.classes.graph.Graph at 0x1ec638bd0>),
#  (u'born in:Predicate:6', <networkx.classes.graph.Graph at 0x1ec638a90>),
#  (u'born in:Predicate:7', <networkx.classes.graph.Graph at 0x1ec638d50>),
#  (u'1955:Entity', <networkx.classes.graph.Graph at 0x1ec638f50>),
#  (u'born in:Predicate:8', <networkx.classes.graph.Graph at 0x1ec638910>),
#  (u'born into:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644250>),
#  (u'adoptive families steven paul jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644550>),
#  (u'born on:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644590>),
#  (u'5:00 am , february 24 , 2020 steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644810>),
#  (u'born on:Predicate:10', <networkx.classes.graph.Graph at 0x1ec644950>),
#  (u'24 february 1955:Entity', <networkx.classes.graph.Graph at 0x1ec644050>),
#  (u'born on:Predicate:2', <networkx.classes.graph.Graph at 0x1ec638e10>),
#  (u'born on:Predicate:3', <networkx.classes.graph.Graph at 0x1ec644c10>),
#  (u'born on:Predicate:4', <networkx.classes.graph.Graph at 0x1ec644c50>),
#  (u'2 1.88 m mini bio 1 steven paul jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638090>),
#  (u'born on:Predicate:5', <networkx.classes.graph.Graph at 0x1ec644690>),
#  (u'born on:Predicate:6', <networkx.classes.graph.Graph at 0x1ec644510>),
#  (u'born on:Predicate:7', <networkx.classes.graph.Graph at 0x1ec644bd0>),
#  (u'apple computer:Entity', <networkx.classes.graph.Graph at 0x1ec545090>),
#  (u'born on:Predicate:8', <networkx.classes.graph.Graph at 0x1ec6a63d0>),
#  (u'17 may 1978:Entity', <networkx.classes.graph.Graph at 0x1ec6a65d0>),
#  (u'born on:Predicate:9', <networkx.classes.graph.Graph at 0x1ec6a6610>),
#  (u'born out:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6710>),
#  (u'born:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6990>),
#  (u'born:Predicate:2', <networkx.classes.graph.Graph at 0x1ec6a6950>),
#  (u'adoption jobs:Entity', <networkx.classes.graph.Graph at 0x252ab8a10>),
#  (u'born:Predicate:4', <networkx.classes.graph.Graph at 0x252ab8a50>),
#  (u'born:Predicate:5', <networkx.classes.graph.Graph at 0x252aa6d10>),
#  (u'born:Predicate:6', <networkx.classes.graph.Graph at 0x252aa6c90>),
#  (u'born:Predicate:7', <networkx.classes.graph.Graph at 0x252b27310>),
#  (u'born:Predicate:8', <networkx.classes.graph.Graph at 0x1ec644350>),
#  (u'born:Predicate:9', <networkx.classes.graph.Graph at 0x252b27510>),
#  (u'adoptive father:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f190>),
#  (u'adoptive parents in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f4d0>),
#  (u'baig:Entity', <networkx.classes.graph.Graph at 0x252c1f550>),
#  (u'abdulfattah:Entity', <networkx.classes.graph.Graph at 0x1ec638510>),
#  (u'biological father:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec55bc10>),
#  (u'biological father:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252aa68d0>),
#  (u'biological mother:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f410>),
#  (u'birth after:Predicate:1', <networkx.classes.graph.Graph at 0x1ec574610>),
#  (u'birth family during:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252b27f10>),
#  (u'birth mother out:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1fa50>),
#  (u'brennan:Entity', <networkx.classes.graph.Graph at 0x252c1fbd0>),
#  (u'cupertino:Entity', <networkx.classes.graph.Graph at 0x252c1fc10>),
#  (u'edward c. steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8910>),
#  (u'february 24 , 1955:Entity', <networkx.classes.graph.Graph at 0x252bd8850>),
#  (u'joanne schieble simpson:Entity',
#   <networkx.classes.graph.Graph at 0x252cbcf10>),
#  (u'joanne schieble:Entity', <networkx.classes.graph.Graph at 0x1ec55be90>),
#  (u'2011:Entity', <networkx.classes.graph.Graph at 0x252d2de90>),
#  (u'brennan-jobs by:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252d42c50>),
#  (u'apple co-founder steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec55bfd0>),
#  (u'death in:Predicate:1', <networkx.classes.graph.Graph at 0x252db2090>),
#  (u'find:Predicate:1', <networkx.classes.graph.Graph at 0x252db26d0>),
#  (u'jobs as:Predicate:1', <networkx.classes.graph.Graph at 0x252db2a90>),
#  (u'jobs as:Predicate:2', <networkx.classes.graph.Graph at 0x252db2c10>),
#  (u'jobs as:Predicate:3', <networkx.classes.graph.Graph at 0x252db2d90>),
#  (u'graphisoft park:Entity', <networkx.classes.graph.Graph at 0x1ec5456d0>),
#  (u'jobs at:Predicate:1', <networkx.classes.graph.Graph at 0x252db2dd0>),
#  (u'jobs because:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f090>),
#  (u'jobs by:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f1d0>),
#  (u'jobs from:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f3d0>),
#  (u'jobs in:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f490>),
#  (u'jobs in:Predicate:2', <networkx.classes.graph.Graph at 0x252a4f6d0>),
#  (u'jobs in:Predicate:3', <networkx.classes.graph.Graph at 0x252a4f650>),
#  (u'1954:Entity', <networkx.classes.graph.Graph at 0x252a4f950>),
#  (u'fell in:Predicate:1', <networkx.classes.graph.Graph at 0x252a4fa50>),
#  (u'jobs in:Predicate:4', <networkx.classes.graph.Graph at 0x252a4fad0>),
#  (u'jobs in:Predicate:5', <networkx.classes.graph.Graph at 0x252a4fc10>),
#  (u'jobs in:Predicate:6', <networkx.classes.graph.Graph at 0x252a4fdd0>),
#  (u'jobs in:Predicate:7', <networkx.classes.graph.Graph at 0x252ce3110>),
#  (u'jobs of:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644850>),
#  (u'jobs on:Predicate:1', <networkx.classes.graph.Graph at 0x252e84050>),
#  (u'jobs on:Predicate:2', <networkx.classes.graph.Graph at 0x252e84190>),
#  (u'jobs on:Predicate:3', <networkx.classes.graph.Graph at 0x252e841d0>),
#  (u'jobs outside:Predicate:1', <networkx.classes.graph.Graph at 0x252e844d0>),
#  (u'1985 jobs:Entity', <networkx.classes.graph.Graph at 0x252ab8b90>),
#  (u'announcement of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f18910>),
#  (u'became:Predicate:1', <networkx.classes.graph.Graph at 0x252f694d0>),
#  (u'became with:Predicate:1', <networkx.classes.graph.Graph at 0x252a4fa10>),
#  (u'became:Predicate:2', <networkx.classes.graph.Graph at 0x252f69550>),
#  (u'became:Predicate:3', <networkx.classes.graph.Graph at 0x252a4fe50>),
#  (u'brought:Predicate:2', <networkx.classes.graph.Graph at 0x252f69750>),
#  (u'brought:Predicate:1', <networkx.classes.graph.Graph at 0x252f69890>),
#  (u'co-found:Predicate:1', <networkx.classes.graph.Graph at 0x252f69190>),
#  (u'co-founded:Predicate:1', <networkx.classes.graph.Graph at 0x252db2850>),
#  (u'apple computers:Entity', <networkx.classes.graph.Graph at 0x252f69bd0>),
#  (u'apple computer inc:Entity', <networkx.classes.graph.Graph at 0x1ec545c10>),
#  (u'found:Predicate:1', <networkx.classes.graph.Graph at 0x252f69f90>),
#  (u'fame:Entity', <networkx.classes.graph.Graph at 0x252f69dd0>),
#  (u'founded for:Predicate:1', <networkx.classes.graph.Graph at 0x2530520d0>),
#  (u'igod:Predicate:1', <networkx.classes.graph.Graph at 0x253052190>),
#  (u'important part of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052290>),
#  (u'big part of:Predicate:1', <networkx.classes.graph.Graph at 0x253052510>),
#  (u'big believer in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052650>),
#  (u'important persons in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052790>),
#  (u'inventor:Type', <networkx.classes.graph.Graph at 0x252bd83d0>),
#  (u'jobs powerless within:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2530c2d90>),
#  (u'jobs that:Predicate:1', <networkx.classes.graph.Graph at 0x2530c2e50>),
#  (u'jobs that:Predicate:2', <networkx.classes.graph.Graph at 0x2530c2ed0>),
#  (u'jobs through:Predicate:1', <networkx.classes.graph.Graph at 0x252d2d090>),
#  (u'jobs until:Predicate:1', <networkx.classes.graph.Graph at 0x252e840d0>),
#  (u'jobs while:Predicate:1', <networkx.classes.graph.Graph at 0x2531193d0>),
#  (u'jobs while:Predicate:2', <networkx.classes.graph.Graph at 0x253119550>),
#  (u'jobs while:Predicate:3', <networkx.classes.graph.Graph at 0x253119490>),
#  (u'jobs while:Predicate:4', <networkx.classes.graph.Graph at 0x253119690>),
#  (u'enrolled at:Predicate:1', <networkx.classes.graph.Graph at 0x253192450>),
#  (u'allowed:Predicate:1', <networkx.classes.graph.Graph at 0x253192690>),
#  (u'allowed:Predicate:2', <networkx.classes.graph.Graph at 0x253192990>),
#  (u'interested:Predicate:1', <networkx.classes.graph.Graph at 0x2531c7610>),
#  (u'adopted by:Predicate:1', <networkx.classes.graph.Graph at 0x253192110>),
#  (u'adopted by:Predicate:2', <networkx.classes.graph.Graph at 0x2530c2e90>),
#  (u'adopted by:Predicate:3', <networkx.classes.graph.Graph at 0x2531c7f50>),
#  (u'adopted:Predicate:1', <networkx.classes.graph.Graph at 0x252ab8350>),
#  (u'adopted:Predicate:2', <networkx.classes.graph.Graph at 0x252cbce50>),
#  (u'cared about:Predicate:1', <networkx.classes.graph.Graph at 0x25325a150>),
#  (u'child:Entity', <networkx.classes.graph.Graph at 0x25325a290>),
#  (u'coddled:Predicate:1', <networkx.classes.graph.Graph at 0x25325a350>),
#  (u'german-swiss joanne carol schieble:Entity',
#   <networkx.classes.graph.Graph at 0x25325a3d0>),
#  (u'guest:Type', <networkx.classes.graph.Graph at 0x25325a410>),
#  (u'british-born industrial designer:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6dd0>),
#  (u'help of:Predicate:1', <networkx.classes.graph.Graph at 0x25325a4d0>),
#  (u'is that:Predicate:1', <networkx.classes.graph.Graph at 0x252c1f6d0>),
#  (u'jobs:Entity', <networkx.classes.graph.Graph at 0x252bd8390>),
#  (u'disclosed about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6f90>),
#  (u'lisa:Entity', <networkx.classes.graph.Graph at 0x25325af90>),
#  (u'lost interview schieble:Entity',
#   <networkx.classes.graph.Graph at 0x2532c6210>),
#  (u'1983:Entity', <networkx.classes.graph.Graph at 0x2532c63d0>),
#  (u'lost steve jobs speech from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2532c6610>),
#  (u'consciousness the day before:Entity',
#   <networkx.classes.graph.Graph at 0x252ba0cd0>),
#  (u'death jobs:Entity', <networkx.classes.graph.Graph at 0x252aa6490>),
#  (u'described in:Predicate:1', <networkx.classes.graph.Graph at 0x2532c6e50>),
#  (u'described:Predicate:1', <networkx.classes.graph.Graph at 0x253338050>),
#  (u'described:Predicate:2', <networkx.classes.graph.Graph at 0x2533380d0>),
#  (u'died at:Predicate:1', <networkx.classes.graph.Graph at 0x252d42f50>),
#  (u'died at:Predicate:2', <networkx.classes.graph.Graph at 0x252db2350>),
#  (u'died at:Predicate:3', <networkx.classes.graph.Graph at 0x252d42e50>),
#  (u'died in:Predicate:1', <networkx.classes.graph.Graph at 0x252e84410>),
#  (u'died of:Predicate:1', <networkx.classes.graph.Graph at 0x252e84550>),
#  (u'died of:Predicate:2', <networkx.classes.graph.Graph at 0x253338510>),
#  (u'died with:Predicate:1', <networkx.classes.graph.Graph at 0x253338590>),
#  (u'died:Predicate:1', <networkx.classes.graph.Graph at 0x2533385d0>),
#  (u'january 2001:Entity', <networkx.classes.graph.Graph at 0x253338790>),
#  (u'last words jobs:Entity', <networkx.classes.graph.Graph at 0x253338950>),
#  (u'lost:Predicate:1', <networkx.classes.graph.Graph at 0x2533387d0>),
#  (u'made at:Predicate:1', <networkx.classes.graph.Graph at 0x253338d10>),
#  (u'married because:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec574310>),
#  (u'married in:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9790>),
#  (u'1991:Entity', <networkx.classes.graph.Graph at 0x2533f98d0>),
#  (u'married in:Predicate:2', <networkx.classes.graph.Graph at 0x2533f9650>),
#  (u'married in:Predicate:3', <networkx.classes.graph.Graph at 0x2533f9a50>),
#  (u'laurene powell:Entity', <networkx.classes.graph.Graph at 0x2533f9b90>),
#  (u'march 18 , 1991:Entity', <networkx.classes.graph.Graph at 0x2533f9910>),
#  (u'married on:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9c10>),
#  (u'married with:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9d90>),
#  (u'liberal arts:Entity', <networkx.classes.graph.Graph at 0x2533f9c90>),
#  (u'married with:Predicate:2', <networkx.classes.graph.Graph at 0x2533f9ed0>),
#  (u'married:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9f50>),
#  (u'married:Predicate:2', <networkx.classes.graph.Graph at 0x2534a1110>),
#  (u'married:Predicate:3', <networkx.classes.graph.Graph at 0x2534a1190>),
#  (u'married:Predicate:4', <networkx.classes.graph.Graph at 0x1ec644a10>),
#  (u'four times:Entity', <networkx.classes.graph.Graph at 0x2534a12d0>),
#  (u'married:Predicate:5', <networkx.classes.graph.Graph at 0x2534a1310>),
#  (u'biological parents:Entity', <networkx.classes.graph.Graph at 0x2534a1410>),
#  (u'married:Predicate:6', <networkx.classes.graph.Graph at 0x252aa6850>),
#  (u'clara hagopian:Entity', <networkx.classes.graph.Graph at 0x2531c7350>),
#  (u'married:Predicate:7', <networkx.classes.graph.Graph at 0x252b27b90>),
#  (u'married:Predicate:8', <networkx.classes.graph.Graph at 0x2534a1710>),
#  (u'mature:Type', <networkx.classes.graph.Graph at 0x2534a1750>),
#  (u'ms schieble:Entity', <networkx.classes.graph.Graph at 0x252cbcc10>),
#  (u'interim chief the new york times:Entity',
#   <networkx.classes.graph.Graph at 0x2534a1ad0>),
#  (u'names jobs as:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f050>),
#  (u'odd individual:Type', <networkx.classes.graph.Graph at 0x2534a1c50>),
#  (u'offered:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1d90>),
#  (u'opens:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1e10>),
#  (u'opens at:Predicate:1', <networkx.classes.graph.Graph at 0x25350c190>),
#  (u'opposed:Predicate:1', <networkx.classes.graph.Graph at 0x252ce3b90>),
#  (u'opposed:Predicate:2', <networkx.classes.graph.Graph at 0x25350c390>),
#  (u'palo alto:Entity', <networkx.classes.graph.Graph at 0x252ba05d0>),
#  (u'part of:Predicate:1', <networkx.classes.graph.Graph at 0x25350c610>),
#  (u'paul jobs:Entity', <networkx.classes.graph.Graph at 0x25350c890>),
#  (u'coast guard mechanic:Type', <networkx.classes.graph.Graph at 0x25350c990>),
#  (u'paul reinhold jobs:Entity', <networkx.classes.graph.Graph at 0x25350c8d0>),
#  (u'coast guard veteran:Type', <networkx.classes.graph.Graph at 0x25350ca10>),
#  (u'person:Entity', <networkx.classes.graph.Graph at 0x25350cb10>),
#  (u'pixar animation studios:Entity',
#   <networkx.classes.graph.Graph at 0x25350ce10>),
#  (u'profitability jobs on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253573450>),
#  (u'profitability jobs on:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253573550>),
#  (u'profitability jobs on:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253573690>),
#  (u'realize that:Predicate:1', <networkx.classes.graph.Graph at 0x252b27dd0>),
#  (u'3 p.m. on october 5 , 2011:Entity',
#   <networkx.classes.graph.Graph at 0x252499ed0>),
#  (u'home around:Predicate:1', <networkx.classes.graph.Graph at 0x2535de390>),
#  (u'home in:Predicate:1', <networkx.classes.graph.Graph at 0x2535de650>),
#  (u'home of:Predicate:1', <networkx.classes.graph.Graph at 0x2535de6d0>),
#  (u'los altos:Entity', <networkx.classes.graph.Graph at 0x2535de7d0>),
#  (u'mountain view home as:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2535de790>),
#  (u'respiratory arrest:Entity', <networkx.classes.graph.Graph at 0x25325a190>),
#  (u'resulted in:Predicate:1', <networkx.classes.graph.Graph at 0x2535dea90>),
#  (u'run:Predicate:1', <networkx.classes.graph.Graph at 0x2535def10>),
#  (u'run:Predicate:2', <networkx.classes.graph.Graph at 0x2535defd0>),
#  (u'san francisco bay area portal list:Entity',
#   <networkx.classes.graph.Graph at 0x2535dee50>),
#  (u'saved:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2210>),
#  (u'says from:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2590>),
#  (u'says:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2950>),
#  (u'says:Predicate:2', <networkx.classes.graph.Graph at 0x252c1ff10>),
#  (u'service in:Predicate:1', <networkx.classes.graph.Graph at 0x25371b050>),
#  (u'sister patti jobs:Entity', <networkx.classes.graph.Graph at 0x25371b250>),
#  (u'started:Predicate:4', <networkx.classes.graph.Graph at 0x25371bad0>),
#  (u'states that:Predicate:1', <networkx.classes.graph.Graph at 0x25371bed0>),
#  (u'steve jobs aug 21 , 2019 apr 27 , 2017 steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x25371be90>),
#  (u'great:Entity', <networkx.classes.graph.Graph at 0x252b27150>),
#  (u'steve jobs so:Predicate:1', <networkx.classes.graph.Graph at 0x253701690>),
#  (u'steve jobs story:Entity', <networkx.classes.graph.Graph at 0x252ab88d0>),
#  (u'india:Entity', <networkx.classes.graph.Graph at 0x2537019d0>),
#  (u'steve jobs the times of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701a90>),
#  (u'steve jobs theatre:Entity', <networkx.classes.graph.Graph at 0x2536a2110>),
#  (u'steve jobs media:Entity', <networkx.classes.graph.Graph at 0x252aa62d0>),
#  (u'steve jobs timeline of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701dd0>),
#  (u'steve jobs will:Entity', <networkx.classes.graph.Graph at 0x253701f10>),
#  (u'diagnosed with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2538caf10>),
#  (u'introduced:Predicate:1', <networkx.classes.graph.Graph at 0x2531c7cd0>),
#  (u'icloud:Entity', <networkx.classes.graph.Graph at 0x2538ca4d0>),
#  (u'introduced:Predicate:10', <networkx.classes.graph.Graph at 0x2539579d0>),
#  (u'introduced:Predicate:2', <networkx.classes.graph.Graph at 0x253957bd0>),
#  (u'introduced:Predicate:4', <networkx.classes.graph.Graph at 0x253957e10>),
#  (u'introduced:Predicate:5', <networkx.classes.graph.Graph at 0x253957ed0>),
#  (u'introduced:Predicate:6', <networkx.classes.graph.Graph at 0x253957e90>),
#  (u'introduced:Predicate:7', <networkx.classes.graph.Graph at 0x2531925d0>),
#  (u'introduced:Predicate:8', <networkx.classes.graph.Graph at 0x253992110>),
#  (u'introduced:Predicate:9', <networkx.classes.graph.Graph at 0x252ab8690>),
#  (u'iphone:Entity', <networkx.classes.graph.Graph at 0x253802090>),
#  (u'jobs steve jobs:Entity', <networkx.classes.graph.Graph at 0x252bd8290>),
#  (u'after jobs:Entity', <networkx.classes.graph.Graph at 0x25325a7d0>),
#  (u'death:Predicate:1', <networkx.classes.graph.Graph at 0x253992590>),
#  (u'iger:Entity', <networkx.classes.graph.Graph at 0x253992650>),
#  (u'23-year-old students:Entity',
#   <networkx.classes.graph.Graph at 0x253992ad0>),
#  (u'met as:Predicate:1', <networkx.classes.graph.Graph at 0x253992b10>),
#  (u'met:Predicate:1', <networkx.classes.graph.Graph at 0x253992bd0>),
#  (u'criticized:Predicate:1', <networkx.classes.graph.Graph at 0x25350c3d0>),
#  (u'dell:Entity', <networkx.classes.graph.Graph at 0x253992c90>),
#  (u'first jobs:Entity', <networkx.classes.graph.Graph at 0x25325aa50>),
#  (u'met:Predicate:3', <networkx.classes.graph.Graph at 0x252b27390>),
#  (u'disney steve jobs:Entity', <networkx.classes.graph.Graph at 0x252ab8e90>),
#  (u'met:Predicate:4', <networkx.classes.graph.Graph at 0x253992ed0>),
#  (u'known as:Predicate:1', <networkx.classes.graph.Graph at 0x253859ed0>),
#  (u'one:Entity', <networkx.classes.graph.Graph at 0x25350ce50>),
#  (u'pancreatic cancer:Entity', <networkx.classes.graph.Graph at 0x253a13510>),
#  (u'fund:Predicate:1', <networkx.classes.graph.Graph at 0x252aa6690>),
#  (u'pixar:Entity', <networkx.classes.graph.Graph at 0x253a13750>),
#  (u'new questions:Entity', <networkx.classes.graph.Graph at 0x253a13a90>),
#  (u'raised about:Predicate:1', <networkx.classes.graph.Graph at 0x253a13990>),
#  (u'apple jobs:Entity', <networkx.classes.graph.Graph at 0x1ec638250>),
#  (u'raised by:Predicate:1', <networkx.classes.graph.Graph at 0x253a13c50>),
#  (u'raised:Predicate:1', <networkx.classes.graph.Graph at 0x253a13d50>),
#  (u'mother:Entity', <networkx.classes.graph.Graph at 0x252aa6b50>),
#  (u'raised:Predicate:2', <networkx.classes.graph.Graph at 0x2533f9550>),
#  (u'held:Predicate:1', <networkx.classes.graph.Graph at 0x253a8c750>),
#  (u'oct. 16:Entity', <networkx.classes.graph.Graph at 0x253a8c710>),
#  (u'private steve jobs memorial:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8f90>),
#  (u"'d:Predicate:1", <networkx.classes.graph.Graph at 0x253b16dd0>),
#  (u'accepted:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1ed0>),
#  (u'advice:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c790>),
#  (u'agree:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c850>),
#  (u'announced that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2538afd10>),
#  (u'announced:Predicate:1', <networkx.classes.graph.Graph at 0x253b5ca90>),
#  (u'announced:Predicate:2', <networkx.classes.graph.Graph at 0x253b5cad0>),
#  (u'announced:Predicate:3', <networkx.classes.graph.Graph at 0x253b5cb90>),
#  (u'announces:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2e10>),
#  (u'become:Predicate:1', <networkx.classes.graph.Graph at 0x252f69650>),
#  (u'become:Predicate:2', <networkx.classes.graph.Graph at 0x252f695d0>),
#  (u'become:Predicate:3', <networkx.classes.graph.Graph at 0x253b5cf90>),
#  (u'believe in:Predicate:1', <networkx.classes.graph.Graph at 0x253119b50>),
#  (u'bought:Predicate:1', <networkx.classes.graph.Graph at 0x252e845d0>),
#  (u'built:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1590>),
#  (u'buried:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1650>),
#  (u'buys:Predicate:1', <networkx.classes.graph.Graph at 0x253ba12d0>),
#  (u'called:Predicate:1', <networkx.classes.graph.Graph at 0x2532c6f90>),
#  (u'called:Predicate:2', <networkx.classes.graph.Graph at 0x253ba1790>),
#  (u'called:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1910>),
#  (u'attitude:Entity', <networkx.classes.graph.Graph at 0x2530c2750>),
#  (u'came from:Predicate:1', <networkx.classes.graph.Graph at 0x2530c2790>),
#  (u'came in:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1a90>),
#  (u'came:Predicate:1', <networkx.classes.graph.Graph at 0x252f69a50>),
#  (u'came:Predicate:2', <networkx.classes.graph.Graph at 0x253ba17d0>),
#  (u'came:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1d90>),
#  (u'caused:Predicate:1', <networkx.classes.graph.Graph at 0x2535dec10>),
#  (u'close encounters with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec4d8d10>),
#  (u'collect:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1f50>),
#  (u'compared:Predicate:1', <networkx.classes.graph.Graph at 0x253119390>),
#  (u'compared:Predicate:2', <networkx.classes.graph.Graph at 0x253bc2210>),
#  (u'computer:Entity', <networkx.classes.graph.Graph at 0x253bc22d0>),
#  (u'convinced that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253573cd0>),
#  (u'convinced:Predicate:1', <networkx.classes.graph.Graph at 0x253ba11d0>),
#  (u'decided:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2dd0>),
#  (u'decided:Predicate:2', <networkx.classes.graph.Graph at 0x253b16e90>),
#  (u'aqua:Entity', <networkx.classes.graph.Graph at 0x253bc2650>),
#  (u'demoed:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2710>),
#  (u'designed after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69ed0>),
#  (u'designed:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6a50>),
#  (u'desktop video:Entity', <networkx.classes.graph.Graph at 0x253bc28d0>),
#  (u'discovered:Predicate:1', <networkx.classes.graph.Graph at 0x252f69c90>),
#  (u'engaging with:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a60d0>),
#  (u'everyone:Entity', <networkx.classes.graph.Graph at 0x253bc2a10>),
#  (u'ex-girlfriend from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f790>),
#  (u'a memoir of:Predicate:1', <networkx.classes.graph.Graph at 0x252d42b50>),
#  (u'ex-girlfriend pens memoir on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2b50>),
#  (u'exacted:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2c10>),
#  (u'biography:Entity', <networkx.classes.graph.Graph at 0x2537b0dd0>),
#  (u'explained in:Predicate:1', <networkx.classes.graph.Graph at 0x252ce3690>),
#  (u'explained that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2cd0>),
#  (u'explained:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2c50>),
#  (u'feeling:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2c10>),
#  (u'felt:Predicate:1', <networkx.classes.graph.Graph at 0x253c1f090>),
#  (u'fired from:Predicate:1', <networkx.classes.graph.Graph at 0x252e84650>),
#  (u'formed:Predicate:1', <networkx.classes.graph.Graph at 0x252f69cd0>),
#  (u'half staff for:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ad89d0>),
#  (u'hands dirty in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1f350>),
#  (u'happened after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db2990>),
#  (u'hardest-working in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1fdd0>),
#  (u'helped:Predicate:1', <networkx.classes.graph.Graph at 0x25325a590>),
#  (u'high school chrisann brennan:Entity',
#   <networkx.classes.graph.Graph at 0x253c1f710>),
#  (u'first:Entity', <networkx.classes.graph.Graph at 0x252aa6b90>),
#  (u'hired:Predicate:1', <networkx.classes.graph.Graph at 0x253992fd0>),
#  (u'historic:Predicate:1', <networkx.classes.graph.Graph at 0x253aea050>),
#  (u'immigration policies:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701e10>),
#  (u'inaugurated:Predicate:1', <networkx.classes.graph.Graph at 0x253c1fd10>),
#  (u'insistence that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1fe10>),
#  (u'interview with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1fe50>),
#  (u'introduces:Predicate:1', <networkx.classes.graph.Graph at 0x2531c7e50>),
#  (u'introducing:Predicate:1', <networkx.classes.graph.Graph at 0x25350c450>),
#  (u'invented:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b090>),
#  (u'launch:Entity', <networkx.classes.graph.Graph at 0x253c7b1d0>),
#  (u'learn from:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b110>),
#  (u'06 oct 2011:Entity', <networkx.classes.graph.Graph at 0x252c1fe50>),
#  (u'legacy:Predicate:1', <networkx.classes.graph.Graph at 0x252310c10>),
#  (u'life with:Predicate:2', <networkx.classes.graph.Graph at 0x252f18e90>),
#  (u'listed as:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b490>),
#  (u'looked for:Predicate:1', <networkx.classes.graph.Graph at 0x253c1f150>),
#  (u'loved:Predicate:1', <networkx.classes.graph.Graph at 0x25325a1d0>),
#  (u'mac os 9:Entity', <networkx.classes.graph.Graph at 0x253b5cb50>),
#  (u'ipod:Entity', <networkx.classes.graph.Graph at 0x253b5cb10>),
#  (u'made:Predicate:4', <networkx.classes.graph.Graph at 0x252aa64d0>),
#  (u'mistake of:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b890>),
#  (u'name along:Predicate:1', <networkx.classes.graph.Graph at 0x2534a1c10>),
#  ('ne:Type', <networkx.classes.graph.Graph at 0x253c7ba50>),
#  (u'negotiated:Predicate:1', <networkx.classes.graph.Graph at 0x253b161d0>),
#  (u'negotiated:Predicate:2', <networkx.classes.graph.Graph at 0x253c7bc10>),
#  (u'nextcomputer:Entity', <networkx.classes.graph.Graph at 0x253c7bc90>),
#  (u'official memorial page for:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69450>),
#  (u'oversaw:Predicate:1', <networkx.classes.graph.Graph at 0x253992310>),
#  (u'oversaw:Predicate:2', <networkx.classes.graph.Graph at 0x253c7be10>),
#  (u'own money in:Predicate:1', <networkx.classes.graph.Graph at 0x253802e10>),
#  (u'passions as:Predicate:1', <networkx.classes.graph.Graph at 0x253c7be90>),
#  (u'pcs:Entity', <networkx.classes.graph.Graph at 0x253cd0090>),
#  (u'perfectionist demands on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252cbc1d0>),
#  (u'now:Entity', <networkx.classes.graph.Graph at 0x253cd0250>),
#  (u'private spirituality:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cd0290>),
#  (u'parents:Entity', <networkx.classes.graph.Graph at 0x1ec638b10>),
#  (u'put:Predicate:1', <networkx.classes.graph.Graph at 0x252f69950>),
#  (u'put:Predicate:2', <networkx.classes.graph.Graph at 0x2531c7390>),
#  (u'put:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1e90>),
#  (u'great job:Entity', <networkx.classes.graph.Graph at 0x2537016d0>),
#  (u'raising:Predicate:1', <networkx.classes.graph.Graph at 0x253701610>),
#  (u'rare pancreatic cancer:Entity',
#   <networkx.classes.graph.Graph at 0x253cd05d0>),
#  (u'realized that:Predicate:1', <networkx.classes.graph.Graph at 0x253573d50>),
#  (u'realizing:Predicate:1', <networkx.classes.graph.Graph at 0x253573e10>),
#  (u'liver transplant:Entity', <networkx.classes.graph.Graph at 0x253701510>),
#  (u'recovering after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cd0810>),
#  (u'refused:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c510>),
#  (u'ceo:Entity', <networkx.classes.graph.Graph at 0x253c7b650>),
#  (u'remained:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b790>),
#  (u'resigned in:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2f90>),
#  (u'gap:Entity', <networkx.classes.graph.Graph at 0x253cd0d90>),
#  (u'resigns from:Predicate:1', <networkx.classes.graph.Graph at 0x253cd0e90>),
#  (u'returned without:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253a8cb90>),
#  (u'returned:Predicate:1', <networkx.classes.graph.Graph at 0x252cbc6d0>),
#  (u'apple stock options scandal:Entity',
#   <networkx.classes.graph.Graph at 0x252f18b10>),
#  (u'role in:Predicate:1', <networkx.classes.graph.Graph at 0x253cf6150>),
#  (u'role in:Predicate:2', <networkx.classes.graph.Graph at 0x253cf6250>),
#  (u'said that:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2bd0>),
#  (u'said:Predicate:1', <networkx.classes.graph.Graph at 0x253bc2dd0>),
#  (u'ms simpson:Entity', <networkx.classes.graph.Graph at 0x2534a1a10>),
#  (u'said:Predicate:2', <networkx.classes.graph.Graph at 0x252cbce10>),
#  (u'say about:Predicate:1', <networkx.classes.graph.Graph at 0x253ba1150>),
#  (u'september 1985:Entity', <networkx.classes.graph.Graph at 0x253cf6790>),
#  (u'speculated that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f18d90>),
#  (u'staff in:Predicate:1', <networkx.classes.graph.Graph at 0x253cf6890>),
#  (u'started:Predicate:1', <networkx.classes.graph.Graph at 0x25371be50>),
#  (u'started:Predicate:5', <networkx.classes.graph.Graph at 0x25371bd90>),
#  (u'started:Predicate:7', <networkx.classes.graph.Graph at 0x25371bd10>),
#  (u'started:Predicate:9', <networkx.classes.graph.Graph at 0x25371bc90>),
#  (u'steve jobs:Entity', <networkx.classes.graph.Graph at 0x253cf6b50>),
#  (u'steve:Entity', <networkx.classes.graph.Graph at 0x2537b0410>),
#  (u'steven p. jobs trust:Entity',
#   <networkx.classes.graph.Graph at 0x253e1b110>),
#  (u'named:Predicate:1', <networkx.classes.graph.Graph at 0x25350c850>),
#  (u'subsequent years jobs:Entity',
#   <networkx.classes.graph.Graph at 0x253cd0e10>),
#  (u'take:Predicate:3', <networkx.classes.graph.Graph at 0x253ba1a10>),
#  (u'taking:Predicate:1', <networkx.classes.graph.Graph at 0x2530c2650>),
#  (u'talking about:Predicate:1', <networkx.classes.graph.Graph at 0x253e1b650>),
#  (u'technology:Entity', <networkx.classes.graph.Graph at 0x253e1b690>),
#  (u'tells:Predicate:1', <networkx.classes.graph.Graph at 0x253e1b990>),
#  (u'tensions between:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cf6410>),
#  (u'the next five years:Entity',
#   <networkx.classes.graph.Graph at 0x253e1bb10>),
#  (u'thing about:Predicate:1', <networkx.classes.graph.Graph at 0x252ab8150>),
#  (u'appeared on:Predicate:1', <networkx.classes.graph.Graph at 0x253c7b690>),
#  (u'appeared on:Predicate:2', <networkx.classes.graph.Graph at 0x253992810>),
#  (u'concerns about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253e1bfd0>),
#  (u'course that:Predicate:1', <networkx.classes.graph.Graph at 0x253ea1250>),
#  (u'received:Predicate:1', <networkx.classes.graph.Graph at 0x253ea12d0>),
#  (u'2009 jobs:Entity', <networkx.classes.graph.Graph at 0x25325a950>),
#  (u'stage:Entity', <networkx.classes.graph.Graph at 0x253ea14d0>),
#  (u'taking:Predicate:2', <networkx.classes.graph.Graph at 0x253bc2510>),
#  (u'thinner steve jobs:Entity', <networkx.classes.graph.Graph at 0x253ea1510>),
#  (u'thrown out:Predicate:1', <networkx.classes.graph.Graph at 0x253ea17d0>),
#  (u'today:Entity', <networkx.classes.graph.Graph at 0x253ea1650>),
#  (u'told:Predicate:1', <networkx.classes.graph.Graph at 0x2536a2a90>),
#  (u'told:Predicate:2', <networkx.classes.graph.Graph at 0x253cd0150>),
#  (u'took in:Predicate:1', <networkx.classes.graph.Graph at 0x253cd0490>),
#  (u'took:Predicate:1', <networkx.classes.graph.Graph at 0x25371b510>),
#  (u'took:Predicate:2', <networkx.classes.graph.Graph at 0x253ea1c10>),
#  (u'interest:Entity', <networkx.classes.graph.Graph at 0x253ea1cd0>),
#  (u'took:Predicate:3', <networkx.classes.graph.Graph at 0x253ea1c50>),
#  (u'took:Predicate:4', <networkx.classes.graph.Graph at 0x253ea1e10>),
#  (u'took:Predicate:5', <networkx.classes.graph.Graph at 0x253ea1dd0>),
#  (u'tries:Predicate:1', <networkx.classes.graph.Graph at 0x253701f90>),
#  (u'300 patents:Entity', <networkx.classes.graph.Graph at 0x253f0b210>),
#  (u'underscores:Predicate:1', <networkx.classes.graph.Graph at 0x253f0b2d0>),
#  (u'understood that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2d10>),
#  (u'understood that:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f0b510>),
#  (u'understood:Predicate:1', <networkx.classes.graph.Graph at 0x253f0b610>),
#  (u'rebellious jobs:Entity', <networkx.classes.graph.Graph at 0x252aa67d0>),
#  (u'underwent:Predicate:2', <networkx.classes.graph.Graph at 0x253f0b8d0>),
#  (u'hungary science park:Entity',
#   <networkx.classes.graph.Graph at 0x253119fd0>),
#  (u'steve jobs statue:Entity', <networkx.classes.graph.Graph at 0x252bd8550>),
#  (u'unveiled:Predicate:1', <networkx.classes.graph.Graph at 0x252db2d50>),
#  (u'unveiled:Predicate:2', <networkx.classes.graph.Graph at 0x253f0bd90>),
#  (u'unveiled:Predicate:3', <networkx.classes.graph.Graph at 0x253f0be90>),
#  (u'unveiled:Predicate:4', <networkx.classes.graph.Graph at 0x253f0bf50>),
#  (u'departure:Entity', <networkx.classes.graph.Graph at 0x253f0bfd0>),
#  (u'upcoming:Predicate:1', <networkx.classes.graph.Graph at 0x253f0bc90>),
#  (u'us:Entity', <networkx.classes.graph.Graph at 0x253f76090>),
#  (u'use:Predicate:1', <networkx.classes.graph.Graph at 0x1ec644450>),
#  (u'used:Predicate:1', <networkx.classes.graph.Graph at 0x253f76110>),
#  (u'used:Predicate:2', <networkx.classes.graph.Graph at 0x253f76310>),
#  (u'used:Predicate:3', <networkx.classes.graph.Graph at 0x253f76490>),
#  (u'used:Predicate:4', <networkx.classes.graph.Graph at 0x253f76590>),
#  (u'view of:Predicate:1', <networkx.classes.graph.Graph at 0x1ec6a6850>),
#  (u'vision of:Predicate:1', <networkx.classes.graph.Graph at 0x252bd8150>),
#  (u'want:Predicate:1', <networkx.classes.graph.Graph at 0x252ab82d0>),
#  (u'want:Predicate:2', <networkx.classes.graph.Graph at 0x253d35fd0>),
#  (u'wanted:Predicate:1', <networkx.classes.graph.Graph at 0x253573110>),
#  (u'wanted:Predicate:2', <networkx.classes.graph.Graph at 0x253f76a10>),
#  (u'wanted:Predicate:3', <networkx.classes.graph.Graph at 0x253f769d0>),
#  (u'wanted:Predicate:4', <networkx.classes.graph.Graph at 0x253f76b90>),
#  (u'biological father steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6590>),
#  (u'steve jobs biological father:Entity',
#   <networkx.classes.graph.Graph at 0x2538af6d0>),
#  (u'1985:Entity', <networkx.classes.graph.Graph at 0x252f18a50>),
#  (u'was in:Predicate:1', <networkx.classes.graph.Graph at 0x253cf6e10>),
#  (u'engineering:Entity', <networkx.classes.graph.Graph at 0x253f76e50>),
#  (u'was in:Predicate:3', <networkx.classes.graph.Graph at 0x253f76e10>),
#  (u'was on:Predicate:1', <networkx.classes.graph.Graph at 0x253f76ed0>),
#  (u'atari:Entity', <networkx.classes.graph.Graph at 0x253cd0ed0>),
#  (u'video game designer:Type', <networkx.classes.graph.Graph at 0x253ffa110>),
#  (u'was with:Predicate:1', <networkx.classes.graph.Graph at 0x2537b0150>),
#  (u'went:Predicate:2', <networkx.classes.graph.Graph at 0x2537b0bd0>),
#  (u'were among:Predicate:1', <networkx.classes.graph.Graph at 0x253b5c610>),
#  (u'many years later:Entity', <networkx.classes.graph.Graph at 0x253ffa410>),
#  (u'wife laurene:Predicate:1', <networkx.classes.graph.Graph at 0x253ffa350>),
#  (u'laurene:Entity', <networkx.classes.graph.Graph at 0x2533f9bd0>),
#  (u'wife:Predicate:1', <networkx.classes.graph.Graph at 0x2533f9810>),
#  (u'special grammy:Entity', <networkx.classes.graph.Graph at 0x253ffa650>),
#  (u'wins:Predicate:1', <networkx.classes.graph.Graph at 0x253ffa750>),
#  (u'wins:Predicate:2', <networkx.classes.graph.Graph at 0x253ffa890>),
#  (u'woodside mansion:Entity', <networkx.classes.graph.Graph at 0x2532c6810>),
#  (u'worked with:Predicate:1', <networkx.classes.graph.Graph at 0x253ffa8d0>),
#  (u'working:Predicate:1', <networkx.classes.graph.Graph at 0x253ffaa10>),
#  (u'wozniak jobs:Entity', <networkx.classes.graph.Graph at 0x253ffaad0>),
#  (u'writer steve martin:Entity',
#   <networkx.classes.graph.Graph at 0x253ffac10>),
#  (u'steve jobs isaacson:Entity',
#   <networkx.classes.graph.Graph at 0x252aa65d0>),
#  (u'writes that:Predicate:1', <networkx.classes.graph.Graph at 0x253a8c3d0>),
#  (u'writes that:Predicate:2', <networkx.classes.graph.Graph at 0x253ffad50>),
#  (u'wrote of:Predicate:1', <networkx.classes.graph.Graph at 0x252ce3c50>),
#  (u'wrote:Predicate:1', <networkx.classes.graph.Graph at 0x252a4f390>),
#  (u'yesterday:Entity', <networkx.classes.graph.Graph at 0x253ffae90>),
#  (u'grew:Predicate:1', <networkx.classes.graph.Graph at 0x253992390>),
#  (u'young steve jobs:Entity', <networkx.classes.graph.Graph at 0x254049250>),
#  (u'\u2019s:Predicate:1', <networkx.classes.graph.Graph at 0x254049310>)]

# %%
answer_type = open(f4, 'r')
ans_type = set()
for line in answer_type:
    ans_type.add(line.strip())

# %%
answer_type

# %%
ans_type

# %%
match_flag = 0
unique_nodes = set()
tree_pot = {}  # trees with potential answers
tc = 0
ans_tree = []

# %%
if Type_Filtering_flag == 1:
    candidate_set = set()
    # Check number of candidate answers
    for (v, T) in GST_set:
        for n in T.nodes():
            nn = n.split(':')
            if nn[1] == 'Entity' and n not in corner:  # Non entities and Cornernerstones are removed
                candidate_set.add(n)

    if len(candidate_set) >= 10:
        type_threshold = threshold
    else:
        type_threshold = -1
else:
    if Type_Filtering_flag == 0:
        type_threshold = -1
    else:
        type_threshold = threshold

# %%
gt1 = set(['unknown'])

# %%
def get_type_simi(n0, G, ans_type, gdict):
    veclen = 300
    term_types = set()
    for (n1, n2) in G.edges():
        if n0 == n2 and n1.split(':')[1] == 'Type':
            term_types.add(n1.split(':')[0])
        else:
            if n0 == n1 and n2.split(':')[1] == 'Type':
                term_types.add(n2.split(':')[0])

    # if verbose:
    # print "Answer type, term type ",ans_type,term_types
    # gdict=word_vectors

    if len(term_types) == 0 or len(
            ans_type) == 0:  # if answer does not have type or node n0 does not have type, keep n0
        return 1.0

    if MAX_MATCH == 1:
        maxval = 0.0

        for n1 in term_types:
            for n2 in ans_type:
                val = cosine_similarity_MAX_MATCH(n1, n2, gdict)
                if val > maxval:
                    maxval = val

    else:
        t_dict = {}
        a_dict = {}

        for n in term_types:
            nw1 = n.split()
            avec = np.zeros(veclen)
            c = 0.0
            for el in nw1:
                if el in gdict and el.lower() not in stop_list:
                    avec = np.add(avec, np.array(gdict[el]))
                    c += 1.0
            if c > 0:
                avec = np.divide(avec, c)

            t_dict[n] = avec.tolist()

        for n in ans_type:
            nw1 = n.split()
            avec = np.zeros(veclen)
            c = 0.0
            for el in nw1:
                if el in gdict and el.lower() not in stop_list:
                    avec = np.add(avec, np.array(gdict[el]))
                    c += 1.0
            if c > 0:
                avec = np.divide(avec, c)

            a_dict[n] = avec.tolist()

        maxval = 0.0

        for n1 in t_dict:
            for n2 in a_dict:
                val = cosine_similarity(t_dict[n1], a_dict[n2])
                if val > maxval:
                    maxval = val
    return maxval

# %%
def cosine_similarity_MAX_MATCH(a, b, gdict):
    a = a.lower()
    aw1 = a.replace('-', ' ').split()
    b = b.lower()
    bw1 = b.replace('-', ' ').split()

    max_match = -1
    for el1 in aw1:
        if el1 in gdict and el1 not in stop_list:
            avec = gdict[el1]
            for el2 in bw1:
                if el2 in gdict and el2 not in stop_list:
                    bvec = gdict[el2]
                    val = cosine_similarity(avec, bvec)
                    if val > max_match:
                        max_match = val
    return max_match

# %%
stop_list = {'a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and', 'any', 'are', 'aren\'t',
             'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can\'t',
             'cannot', 'could', 'couldn\'t', 'did', 'didn\'t', 'do', 'does', 'doesn\'t', 'doing', 'don\'t', 'down',
             'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn\'t', 'has', 'hasn\'t', 'have', 'haven\'t',
             'having', 'he', 'he\'d', 'he\'ll', 'he\'s', 'her', 'here', 'here\'s', 'hers', 'herself', 'him', 'himself',
             'his', 'how', 'how\'s', 'i', 'i\'d', 'i\'ll', 'i\'m', 'i\'ve', 'if', 'in', 'into', 'is', 'isn\'t', 'it',
             'it\'s', 'its', 'itself', 'let\'s', 'me', 'more', 'most', 'mustn\'t', 'my', 'myself', 'no', 'nor', 'not',
             'of', 'off', 'on', 'once', 'only', 'or', 'other', 'ought', 'our', 'ours	ourselves', 'out', 'over',
             'own', 'same', 'shan\'t', 'she', 'she\'d', 'she\'ll', 'she\'s', 'should', 'shouldn\'t', 'so', 'some',
             'such', 'than', 'that', 'that\'s', 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there',
             'there\'s', 'these', 'they', 'they\'d', 'they\'ll', 'they\'re', 'they\'ve', 'this', 'those', 'through',
             'to', 'too', 'under', 'until', 'up', 'very', 'was', 'wasn\'t', 'we', 'we\'d', 'we\'ll', 'we\'re', 'we\'ve',
             'were', 'weren\'t', 'what', 'what\'s', 'when', 'when\'s', 'where', 'where\'s', 'which', 'while', 'who',
             'who\'s', 'whom', 'why', 'why\'s', 'with', 'won\'t', 'would', 'wouldn\'t', 'you', 'you\'d', 'you\'ll',
             'you\'re', 'you\'ve', 'your', 'yours', 'yourself', 'yourselves'}

# %%
def cosine_similarity(a, b):
    s1 = 0.0
    s2 = 0.0
    s3 = 0.0
    if len(a) != len(b):
        return 0.0
    for i in range(0, len(a)):
        s1 += a[i] * b[i]
        s2 += a[i] * a[i]
        s3 += b[i] * b[i]
    if s2 > 0 and s3 > 0:
        val = (s1 / (math.sqrt(s2) * math.sqrt(s3)))
        val_norm = (val + 1.0) / 2.0
        return val_norm
    else:
        return 0

# %%
for (v, T) in GST_set:
    # if verbose:
    # print "\n\nObtained GST-->",tc,v.encode('utf-8'),T.nodes(),T.edges(),get_cost(T,G)
    # for (n,m) in T.edges():
    # data1=G.get_edge_data(n,m)
    # print "Edges ",n,m,data1['weight'],data1['etype'],data1['wlist']
    # print "\nPotential answers filtered by type -->"

    tree_pot[(v, T)] = set()

    for n in T.nodes():
        nn = n.split(':')

        for gt in gt1:
            if len(nn) > 0:
                if nn[0] == (gt.lower()).decode('utf-8'):
                    match_flag = 1
            else:
                if n == (gt.lower()).decode('utf-8'):
                    match_flag = 1

        if nn[1] == 'Entity' and n not in corner:  # Non entities and Cornernerstones are removed
            type_chk = get_type_simi(n, G, ans_type, gdict)
            if verbose:
                print "\nType match ", n, type_chk

            if type_chk >= type_threshold:  # (len(ans_type)>0 and type_chk>=0.5) or (len(ans_type)==0 and type_chk>=-1):       #Answer type non matching are removed
                tree_pot[(v, T)].add(n)
            # if verbose:
            # print n.encode('utf-8')

    '''
    for n in T.nodes():
        unique_nodes.add(n.encode('utf-8'))
        nn=n.split(':')
        if nn[0]==ans:
            ans_tree.append(tc)
    '''

    tc += 1

# %%
if verbose:
    print "\n\ntrees before merging --->", tree_pot

match = {}

# %%
def issubseq(n1, n2):
    nw1 = (n1.split(':'))[0].split()
    nw2 = (n2.split(':'))[0].split()

    i = 0
    flag = 0
    for j in range(0, len(nw2)):
        if nw1[i].lower() == nw2[j].lower():
            i += 1
            if i == len(nw1):
                flag = 1
                break
    if flag == 1:
        return 1
    else:
        return 0

# %%
# Answer merging
for (v1, T1) in tree_pot:
    for n1 in tree_pot[(v1, T1)]:
        for (v2, T2) in tree_pot:
            for n2 in tree_pot[(v2, T2)]:
                flag = 0
                if n1 != n2:
                    if (n1, n2) in G.edges():
                        data = G.get_edge_data(n1, n2)
                        if data['etype'] == 'Entity_Alignment':
                            flag = 1

                    else:
                        if (n2, n1) in G.edges():
                            data = G.get_edge_data(n2, n1)
                            if data['etype'] == 'Entity_Alignment':
                                flag = 1

                    if flag == 1:  # and len(n2)>len(n1): #merging into the longer answer
                        if n1 not in match:
                            match[n1] = set()
                        match[n1].add(n2)
                        if n2 not in match:
                            match[n2] = set()
                        match[n2].add(n1)

                    else:  # Check Subsequence
                        if issubseq(n1, n2) or issubseq(n2, n1):
                            if n1 not in match:
                                match[n1] = set()
                            match[n1].add(n2)
                            if n2 not in match:
                                match[n2] = set()
                            match[n2].add(n1)
    # print "\nMatch after iteration with n1 ",n1
    # for x in match:
    # print x, match[x]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-d575fc45c950> in <module>()
#      12
#      13                     else:
# ---> 14                         if (n2, n1) in G.edges():
#      15                             data = G.get_edge_data(n2, n1)
#      16                             if data['etype'] == 'Entity_Alignment':
#
# /usr/local/anaconda3/envs/QUES_Test/lib/python2.7/site-packages/networkx/classes/graph.pyc in edges(self, nbunch, data, default)
#    1135
#    1136         """
# -> 1137         return list(self.edges_iter(nbunch, data, default))
#    1138
#    1139     def edges_iter(self, nbunch=None, data=False, default=None):
#
# /usr/local/anaconda3/envs/QUES_Test/lib/python2.7/site-packages/networkx/classes/graph.pyc in edges_iter(self, nbunch, data, default)
#    1209                 for nbr in nbrs:
#    1210                     if nbr not in seen:
# -> 1211                         yield (n, nbr)
#    1212                 seen[n] = 1
#    1213         del seen
#
# KeyboardInterrupt:

# %%
tree_pot
# Out:
# {(u"'d:Predicate:1",
#   <networkx.classes.graph.Graph at 0x253b16dd0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'06 oct 2011:Entity',
#   <networkx.classes.graph.Graph at 0x252c1fe50>): {u'06 oct 2011:Entity', u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'17 may 1978:Entity',
#   <networkx.classes.graph.Graph at 0x1ec6a65d0>): {u'17 may 1978:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'lisa n. brennan jobs:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'1931:Entity',
#   <networkx.classes.graph.Graph at 0x1ec6383d0>): {u'1931:Entity', u'abdulfattah john jandali:Entity', u'abdulfattah:Entity', u'joanne simpson:Entity', u'john \u201d jandali:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'1954:Entity',
#   <networkx.classes.graph.Graph at 0x252a4f950>): {u'1954:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'documentary:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'1955:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638f50>): {u'1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'1983:Entity',
#   <networkx.classes.graph.Graph at 0x2532c63d0>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'1985 jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8b90>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'1985:Entity',
#   <networkx.classes.graph.Graph at 0x252f18a50>): {u'1985:Entity', u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'1991:Entity',
#   <networkx.classes.graph.Graph at 0x2533f98d0>): {u'1991:Entity', u'abdulfattah jandali:Entity', u'joanne schieble:Entity', u'wife laurene:Entity'},
#  (u'1998:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638bd0>): {u'1998:Entity', u'abdulfattah john jandali:Entity', u'august 1995:Entity', u'eve:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'2 1.88 m mini bio 1 steven paul jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638090>): {u'2 1.88 m mini bio 1 steven paul jobs:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'san francisco:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'2009 jobs:Entity',
#   <networkx.classes.graph.Graph at 0x25325a950>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'2011:Entity',
#   <networkx.classes.graph.Graph at 0x252d2de90>): {u'2011:Entity', u'adoptive families steven paul jobs:Entity', u'biographer:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'23-year-old students:Entity',
#   <networkx.classes.graph.Graph at 0x253992ad0>): {u'23-year-old students:Entity',
#   u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'24 february 1955:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644050>): {u'24 february 1955:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'joanne carole schieble:Entity', u'joanne simpson:Entity', u'parents:Entity', u'steven paul jobs 6:Entity', u'students abdul fattah jandali:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'3 p.m. on october 5 , 2011:Entity',
#   <networkx.classes.graph.Graph at 0x252499ed0>): {u'1983:Entity',
#   u'1994:Entity',
#   u'3 p.m. on october 5 , 2011:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'imagination:Entity',
#   u'joanne schieble:Entity',
#   u'memory:Entity',
#   u'respiratory arrest:Entity',
#   u'rolling stone interview:Entity'},
#  (u'300 patents:Entity',
#   <networkx.classes.graph.Graph at 0x253f0b210>): {u'300 patents:Entity', u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'5:00 am , february 24 , 2020 steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644810>): {u'abdulfattah john jandali:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'this day in 1955:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'a memoir of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252d42b50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'abdulfattah:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638510>): {u'abdulfattah jandalie:Entity', u'abdulfattah:Entity', u'jobs:Entity'},
#  (u'accepted:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2534a1ed0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'adopted by:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253192110>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'adopted by:Predicate:2',
#   <networkx.classes.graph.Graph at 0x2530c2e90>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'adopted by:Predicate:3',
#   <networkx.classes.graph.Graph at 0x2531c7f50>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'adopted:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252ab8350>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'adopted:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252cbce50>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'adoption jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8a10>): {u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'adoptive families steven paul jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec644550>): {u'abdulfattah john jandali:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'adoptive father:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f190>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'adoptive parents in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f4d0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'advice:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253b5c790>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'after jobs:Entity',
#   <networkx.classes.graph.Graph at 0x25325a7d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'agree:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253b5c850>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'allowed:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253192690>): {u'abdulfattah jandalie:Entity', u'homestead high school:Entity', u'jobs:Entity'},
#  (u'allowed:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253192990>): {u'abdulfattah jandalie:Entity', u'homestead high school:Entity', u'jobs:Entity'},
#  (u'announced that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2538afd10>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'announced:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253b5ca90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'announced:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253b5cad0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'announced:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253b5cb90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'announcement of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f18910>): {u'adoptive families steven paul jobs:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'move:Entity'},
#  (u'announces:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2e10>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'appeared on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c7b690>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'appeared on:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253992810>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'apple co-founder jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1151af990>): {u'1980s:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'apple co-founder jobs:Entity',
#   u'california:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'the 1970s:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'apple co-founder steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec55bfd0>): {u'2011:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'biographer:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity'},
#  (u'apple computer inc:Entity',
#   <networkx.classes.graph.Graph at 0x1ec545c10>): {u'adoptive families steven paul jobs:Entity',
#   u'apple computer inc:Entity',
#   u'apple computers:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'move:Entity'},
#  (u'apple computer:Entity',
#   <networkx.classes.graph.Graph at 0x1ec545090>): {u'abdulfattah john jandali:Entity', u'apple computer:Entity', u'april 1 , 1976:Entity', u'joanne simpson:Entity', u'parents:Entity', u'purpose:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'apple computers:Entity',
#   <networkx.classes.graph.Graph at 0x252f69bd0>): {u'adoptive families steven paul jobs:Entity', u'apple computers:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'apple jobs:Entity',
#   <networkx.classes.graph.Graph at 0x1ec638250>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'apple stock options scandal:Entity',
#   <networkx.classes.graph.Graph at 0x252f18b10>): {u'abdulfattah jandalie:Entity',
#   u'apple stock options scandal:Entity',
#   u'jobs:Entity'},
#  (u'aqua:Entity',
#   <networkx.classes.graph.Graph at 0x253bc2650>): {u'abdulfattah jandalie:Entity', u'aqua:Entity', u'jobs:Entity'},
#  (u'atari:Entity',
#   <networkx.classes.graph.Graph at 0x253cd0ed0>): {u'abdulfattah jandalie:Entity', u'atari:Entity', u'jobs:Entity'},
#  (u'attitude:Entity',
#   <networkx.classes.graph.Graph at 0x2530c2750>): {u'abdulfattah jandalie:Entity', u'attitude:Entity', u'jobs:Entity'},
#  (u'august 1995:Entity',
#   <networkx.classes.graph.Graph at 0x1ec6386d0>): {u'abdulfattah john jandali:Entity', u'august 1995:Entity', u'erin:Entity', u'eve:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two more children:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'baig:Entity',
#   <networkx.classes.graph.Graph at 0x252c1f550>): {u'abdulfattah jandalie:Entity', u'baig:Entity', u'jobs:Entity'},
#  (u'became with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252a4fa10>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'became:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f694d0>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'became:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252f69550>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'became:Predicate:3',
#   <networkx.classes.graph.Graph at 0x252a4fe50>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'become:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69650>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'become:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252f695d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'become:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253b5cf90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'believe in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253119b50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'big believer in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052650>): {u'adoptive families steven paul jobs:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'move:Entity'},
#  (u'big part of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052510>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'biography:Entity',
#   <networkx.classes.graph.Graph at 0x2537b0dd0>): {u'abdulfattah jandalie:Entity', u'biography:Entity', u'jobs:Entity'},
#  (u'biological father steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6590>): {u'father:Entity',
#   u'syria:Entity'},
#  (u'biological father:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec55bc10>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'biological father:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252aa68d0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'biological mother:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f410>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'biological parents:Entity',
#   <networkx.classes.graph.Graph at 0x2534a1410>): {u'abdulfattah jandali:Entity',
#   u'biological parents:Entity',
#   u'child:Entity',
#   u'joanne schieble:Entity',
#   u'schieble:Entity'},
#  (u'birth after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec574610>): {u'abdulfattah jandalie:Entity', u'brennan:Entity', u'jobs:Entity'},
#  (u'birth family during:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252b27f10>): {u'abdulfattah jandalie:Entity',
#   u'adoptive mother clara:Entity',
#   u'brennan:Entity',
#   u'joanne schieble simpson:Entity',
#   u'jobs:Entity',
#   u'lifetime:Entity'},
#  (u'birth mother out:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1fa50>): {u'abdulfattah jandalie:Entity',
#   u'curiosity:Entity',
#   u'jobs:Entity',
#   u'need:Entity',
#   u'paul:Entity'},
#  (u'born in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec4d84d0>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:2',
#   <networkx.classes.graph.Graph at 0x1ec574110>): {u'1958:Entity', u'1980s:Entity', u'abdulfattah john jandali:Entity', u'apple co-founder jobs:Entity', u'california:Entity', u'joanne simpson:Entity', u'parents:Entity', u'the 1970s:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:3',
#   <networkx.classes.graph.Graph at 0x1ec638210>): {u'1931:Entity', u'1958:Entity', u'abdulfattah john jandali:Entity', u'abdulfattah:Entity', u'joanne simpson:Entity', u'john \u201d jandali:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:4',
#   <networkx.classes.graph.Graph at 0x1ec638790>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'august 1995:Entity', u'erin:Entity', u'eve:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two more children:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:5',
#   <networkx.classes.graph.Graph at 0x1ec638a50>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'biological father:Entity', u'joanne simpson:Entity', u'nine children:Entity', u'parents:Entity', u'prominent syrian family:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:6',
#   <networkx.classes.graph.Graph at 0x1ec638a90>): {u'1958:Entity', u'1998:Entity', u'abdulfattah john jandali:Entity', u'august 1995:Entity', u'eve:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:7',
#   <networkx.classes.graph.Graph at 0x1ec638d50>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born in:Predicate:8',
#   <networkx.classes.graph.Graph at 0x1ec638910>): {u'1955:Entity', u'1958:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born into:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec644250>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'abdulfattah john:Entity', u'american university of beirut:Entity', u'joanne simpson:Entity', u'parents:Entity', u'syria:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec644590>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'adoptive families steven paul jobs:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:10',
#   <networkx.classes.graph.Graph at 0x1ec644950>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'this day in 1955:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:2',
#   <networkx.classes.graph.Graph at 0x1ec638e10>): {u'1958:Entity', u'24 february 1955:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'joanne carole schieble:Entity', u'joanne simpson:Entity', u'parents:Entity', u'steven paul jobs 6:Entity', u'students abdul fattah jandali:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:3',
#   <networkx.classes.graph.Graph at 0x1ec644c10>): {u'1958:Entity', u'abdulfattah jandali:Entity', u'abdulfattah john jandali:Entity', u'awards biological:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:4',
#   <networkx.classes.graph.Graph at 0x1ec644c50>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:5',
#   <networkx.classes.graph.Graph at 0x1ec644690>): {u'1958:Entity', u'2 1.88 m mini bio 1 steven paul jobs:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:6',
#   <networkx.classes.graph.Graph at 0x1ec644510>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'steven paul jobs:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:7',
#   <networkx.classes.graph.Graph at 0x1ec644bd0>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'parents:Entity', u'steven paul:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:8',
#   <networkx.classes.graph.Graph at 0x1ec6a63d0>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'apple computer:Entity', u'april 1 , 1976:Entity', u'joanne simpson:Entity', u'parents:Entity', u'purpose:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born on:Predicate:9',
#   <networkx.classes.graph.Graph at 0x1ec6a6610>): {u'17 may 1978:Entity', u'1958:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'lisa n. brennan jobs:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born out:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6710>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'itunes:Entity', u'joanne simpson:Entity', u'parents:Entity', u'realization:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6990>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'birth mother:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity', u'united states:Entity'},
#  (u'born:Predicate:2',
#   <networkx.classes.graph.Graph at 0x1ec6a6950>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'the future:Entity', u'two university of wisconsin graduate students:Entity', u'world:Entity'},
#  (u'born:Predicate:4',
#   <networkx.classes.graph.Graph at 0x252ab8a50>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'february 24 , 1955:Entity', u'full steven paul jobs:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born:Predicate:5',
#   <networkx.classes.graph.Graph at 0x252aa6d10>): {u'1958:Entity', u'1978:Entity', u'1981:Entity', u'abdulfattah john jandali:Entity', u'bottom:Entity', u'california:Entity', u'father:Entity', u'joanne simpson:Entity', u'lisa:Entity', u'mother:Entity', u'parents:Entity', u'saratoga:Entity', u'three days:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born:Predicate:6',
#   <networkx.classes.graph.Graph at 0x252aa6c90>): {u'1955:Entity', u'1958:Entity', u'abdulfattah john jandali:Entity', u'adoption:Entity', u'apple:Entity', u'joanne simpson:Entity', u'parents:Entity', u'schieble:Entity', u'the future co-founder:Entity', u'the year:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born:Predicate:7',
#   <networkx.classes.graph.Graph at 0x252b27310>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'first child:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'powell:Entity', u'reed:Entity', u'september 1991:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born:Predicate:8',
#   <networkx.classes.graph.Graph at 0x1ec644350>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'joanne schieble:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'born:Predicate:9',
#   <networkx.classes.graph.Graph at 0x252b27510>): {u'1958:Entity', u'abdulfattah john jandali:Entity', u'article history steven paul jobs:Entity', u'joanne simpson:Entity', u'parents:Entity', u'two university of wisconsin graduate students:Entity', u'u.s.:Entity'},
#  (u'bought:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252e845d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'brennan-jobs by:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252d42c50>): {u'2011:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'biographer:Entity',
#   u'birth certificate:Entity',
#   u'birth:Entity',
#   u'brennan:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity'},
#  (u'brennan:Entity',
#   <networkx.classes.graph.Graph at 0x252c1fbd0>): {u'abdulfattah jandalie:Entity', u'brennan:Entity', u'jobs:Entity'},
#  (u'british-born industrial designer:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6dd0>): {u'abdulfattah john jandali:Entity',
#   u'california:Entity',
#   u'february 24 , 1955:Entity',
#   u'joanne simpson:Entity',
#   u'jobs:Entity',
#   u'parents:Entity',
#   u'san francisco:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'brought:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69890>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'brought:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252f69750>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'built:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ba1590>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'buried:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ba1650>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'buys:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ba12d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'called:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2532c6f90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'called:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253ba1790>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'called:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253ba1910>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'came from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2530c2790>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'came in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ba1a90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'came:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69a50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'came:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253ba17d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'came:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253ba1d90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'cared about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x25325a150>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'caused:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2535dec10>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'ceo:Entity',
#   <networkx.classes.graph.Graph at 0x253c7b650>): {u'abdulfattah jandalie:Entity', u'ceo:Entity', u'jobs:Entity'},
#  (u'child:Entity',
#   <networkx.classes.graph.Graph at 0x25325a290>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'child:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'clara hagopian:Entity',
#   <networkx.classes.graph.Graph at 0x2531c7350>): {u'1946:Entity', u'abdulfattah jandali:Entity', u'clara hagopian:Entity', u'coast guard:Entity', u'joanne schieble:Entity'},
#  (u'close encounters with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec4d8d10>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'co-found:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69190>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'co-founded:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db2850>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'coast guard mechanic:Type',
#   <networkx.classes.graph.Graph at 0x25350c990>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'coast guard veteran:Type',
#   <networkx.classes.graph.Graph at 0x25350ca10>): {u'curiosity:Entity',
#   u'need:Entity',
#   u'paul:Entity'},
#  (u'coddled:Predicate:1',
#   <networkx.classes.graph.Graph at 0x25325a350>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'collect:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ba1f50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'compared:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253119390>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'compared:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253bc2210>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'computer:Entity',
#   <networkx.classes.graph.Graph at 0x253bc22d0>): {u'abdulfattah jandalie:Entity', u'computer:Entity', u'jobs:Entity'},
#  (u'concerns about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253e1bfd0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'consciousness the day before:Entity',
#   <networkx.classes.graph.Graph at 0x252ba0cd0>): {u'1983:Entity',
#   u'1994:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'birth:Entity',
#   u'consciousness the day before:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'imagination:Entity',
#   u'joanne schieble:Entity',
#   u'memory:Entity',
#   u'rolling stone interview:Entity'},
#  (u'convinced that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253573cd0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'convinced:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ba11d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'course that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ea1250>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'criticized:Predicate:1',
#   <networkx.classes.graph.Graph at 0x25350c3d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'cupertino:Entity',
#   <networkx.classes.graph.Graph at 0x252c1fc10>): {u'abdulfattah jandalie:Entity', u'cupertino:Entity', u'jobs:Entity'},
#  (u'death in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db2090>): {u'2011:Entity', u'adoptive families steven paul jobs:Entity', u'biographer:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'death jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6490>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'death:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253992590>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'decided:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2dd0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'decided:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253b16e90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'dell:Entity',
#   <networkx.classes.graph.Graph at 0x253992c90>): {u'abdulfattah jandalie:Entity', u'dell:Entity', u'jobs:Entity'},
#  (u'demoed:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2710>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'departure:Entity',
#   <networkx.classes.graph.Graph at 0x253f0bfd0>): {u'abdulfattah jandalie:Entity', u'departure:Entity', u'jobs:Entity'},
#  (u'described in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2532c6e50>): {u'1983:Entity',
#   u'1994:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'imagination:Entity',
#   u'joanne schieble:Entity',
#   u'memory:Entity',
#   u'rolling stone interview:Entity'},
#  (u'described:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253338050>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'described:Predicate:2',
#   <networkx.classes.graph.Graph at 0x2533380d0>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'designed after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69ed0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'designed:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6a50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'desktop video:Entity',
#   <networkx.classes.graph.Graph at 0x253bc28d0>): {u'abdulfattah jandalie:Entity', u'desktop video:Entity', u'jobs:Entity'},
#  (u'diagnosed with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2538caf10>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'died at:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252d42f50>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died at:Predicate:2',
#   <networkx.classes.graph.Graph at 0x252db2350>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died at:Predicate:3',
#   <networkx.classes.graph.Graph at 0x252d42e50>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252e84410>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252e84550>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died of:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253338510>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253338590>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'died:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2533385d0>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity'},
#  (u'disclosed about:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6f90>): {u'adoptive families steven paul jobs:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'lisa:Entity',
#   u'move:Entity'},
#  (u'discovered:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69c90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'disney steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8e90>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'edward c. steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x252ab8910>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'engaging with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a60d0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'engineering:Entity',
#   <networkx.classes.graph.Graph at 0x253f76e50>): {u'abdulfattah jandalie:Entity', u'engineering:Entity', u'jobs:Entity'},
#  (u'enrolled at:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253192450>): {u'abdulfattah jandalie:Entity', u'homestead high school:Entity', u'jobs:Entity'},
#  (u'everyone:Entity',
#   <networkx.classes.graph.Graph at 0x253bc2a10>): {u'abdulfattah jandalie:Entity', u'everyone:Entity', u'jobs:Entity'},
#  (u'ex-girlfriend from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1f790>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'ex-girlfriend pens memoir on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2b50>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'exacted:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2c10>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'explained in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252ce3690>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'explained that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2cd0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'explained:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2c50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'fame:Entity',
#   <networkx.classes.graph.Graph at 0x252f69dd0>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'fame:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'february 24 , 1955:Entity',
#   <networkx.classes.graph.Graph at 0x252bd8850>): {u'1958:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'adoptive families steven paul jobs:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'feeling:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2c10>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'fell in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252a4fa50>): {u'1954:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'documentary:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'felt:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1f090>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'find:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db26d0>): {u'2011:Entity', u'adoptive families steven paul jobs:Entity', u'biographer:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'fired from:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252e84650>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'first jobs:Entity',
#   <networkx.classes.graph.Graph at 0x25325aa50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'first:Entity',
#   <networkx.classes.graph.Graph at 0x252aa6b90>): {u'abdulfattah jandalie:Entity', u'first:Entity', u'jobs:Entity'},
#  (u'formed:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69cd0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'found:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252f69f90>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'founded for:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2530520d0>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'four times:Entity',
#   <networkx.classes.graph.Graph at 0x2534a12d0>): {u'abdulfattah jandali:Entity', u'four times:Entity', u'jandali:Entity', u'joanne schieble:Entity'},
#  (u'fund:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252aa6690>): {u'abdulfattah jandalie:Entity', u'jobs:Entity', u'pixar:Entity'},
#  (u'gap:Entity',
#   <networkx.classes.graph.Graph at 0x253cd0d90>): {u'abdulfattah jandalie:Entity', u'gap:Entity', u'jobs:Entity'},
#  (u'german-swiss joanne carol schieble:Entity',
#   <networkx.classes.graph.Graph at 0x25325a3d0>): {u'abdulfattah jandalie:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'california:Entity',
#   u'february 24 , 1955:Entity',
#   u'german-swiss joanne carol schieble:Entity',
#   u'joanne simpson:Entity',
#   u'jobs:Entity',
#   u'parents:Entity',
#   u'san francisco:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'graphisoft park:Entity',
#   <networkx.classes.graph.Graph at 0x1ec5456d0>): {u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'graphisoft park:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'great job:Entity',
#   <networkx.classes.graph.Graph at 0x2537016d0>): {u'abdulfattah jandalie:Entity', u'great job:Entity', u'jobs:Entity'},
#  (u'great:Entity',
#   <networkx.classes.graph.Graph at 0x252b27150>): {u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'great:Entity', u'honors:Entity', u'joanne schieble:Entity'},
#  (u'grew:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253992390>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'guest:Type',
#   <networkx.classes.graph.Graph at 0x25325a410>): {u'abdulfattah jandalie:Entity', u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'half staff for:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ad89d0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'hands dirty in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1f350>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'happened after:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db2990>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'hardest-working in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252c1fdd0>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'held:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253a8c750>): {u'abdulfattah jandalie:Entity', u'jobs:Entity', u'oct. 16:Entity'},
#  (u'help of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x25325a4d0>): {u'abdulfattah john jandali:Entity', u'california:Entity', u'february 24 , 1955:Entity', u'joanne simpson:Entity', u'jobs:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'helped:Predicate:1',
#   <networkx.classes.graph.Graph at 0x25325a590>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'high school chrisann brennan:Entity',
#   <networkx.classes.graph.Graph at 0x253c1f710>): {u'abdulfattah jandalie:Entity',
#   u'high school chrisann brennan:Entity',
#   u'jobs:Entity'},
#  (u'hired:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253992fd0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'historic:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253aea050>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'home around:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2535de390>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'respiratory arrest:Entity', u'rolling stone interview:Entity'},
#  (u'home in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2535de650>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'respiratory arrest:Entity', u'rolling stone interview:Entity'},
#  (u'home of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2535de6d0>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'respiratory arrest:Entity', u'rolling stone interview:Entity'},
#  (u'hungary science park:Entity',
#   <networkx.classes.graph.Graph at 0x253119fd0>): {u'abdulfattah jandalie:Entity',
#   u'hungary science park:Entity',
#   u'jobs:Entity'},
#  (u'icloud:Entity',
#   <networkx.classes.graph.Graph at 0x2538ca4d0>): {u'abdulfattah jandalie:Entity', u'icloud:Entity', u'jobs:Entity'},
#  (u'iger:Entity',
#   <networkx.classes.graph.Graph at 0x253992650>): {u'abdulfattah jandalie:Entity', u'iger:Entity', u'jobs:Entity'},
#  (u'igod:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052190>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'immigration policies:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701e10>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'important part of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052290>): {u'adoptive families steven paul jobs:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'move:Entity'},
#  (u'important persons in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253052790>): {u'adoptive families steven paul jobs:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'move:Entity'},
#  (u'inaugurated:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1fd10>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'india:Entity',
#   <networkx.classes.graph.Graph at 0x2537019d0>): {u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'india:Entity', u'joanne schieble:Entity', u'tribute:Entity'},
#  (u'insistence that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253c1fe10>): {u'abdulfattah jandalie:Entity',
#   u'jobs:Entity'},
#  (u'interest:Entity',
#   <networkx.classes.graph.Graph at 0x253ea1cd0>): {u'abdulfattah jandalie:Entity', u'interest:Entity', u'jobs:Entity'},
#  (u'interested:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2531c7610>): {u'abdulfattah jandalie:Entity', u'homestead high school:Entity', u'jobs:Entity'},
#  (u'interim chief the new york times:Entity',
# ...
#  (u'today:Entity',
#   <networkx.classes.graph.Graph at 0x253ea1650>): {u'abdulfattah jandalie:Entity', u'jobs:Entity', u'today:Entity'},
#  (u'told:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2536a2a90>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'told:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253cd0150>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'took in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cd0490>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'took:Predicate:1',
#   <networkx.classes.graph.Graph at 0x25371b510>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'took:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253ea1c10>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'took:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253ea1c50>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'took:Predicate:4',
#   <networkx.classes.graph.Graph at 0x253ea1e10>): {u'abdulfattah jandalie:Entity', u'homestead high school:Entity', u'jobs:Entity'},
#  (u'took:Predicate:5',
#   <networkx.classes.graph.Graph at 0x253ea1dd0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'tries:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253701f90>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'underscores:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253f0b2d0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'understood that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253bc2d10>): {u'1958:Entity',
#   u'_ page 165:Entity',
#   u'_ page _ title february 24 , 1955:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'san francisco:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'understood that:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f0b510>): {u'1958:Entity',
#   u'_ page 165:Entity',
#   u'_ page _ title february 24 , 1955:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'san francisco:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'understood:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253f0b610>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'underwent:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f0b8d0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'unveiled:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252db2d50>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'unveiled:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f0bd90>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'unveiled:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253f0be90>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'unveiled:Predicate:4',
#   <networkx.classes.graph.Graph at 0x253f0bf50>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'upcoming:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253f0bc90>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'us:Entity',
#   <networkx.classes.graph.Graph at 0x253f76090>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity', u'us:Entity'},
#  (u'use:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec644450>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'used:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253f76110>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'used:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f76310>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'used:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253f76490>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'used:Predicate:4',
#   <networkx.classes.graph.Graph at 0x253f76590>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'video game designer:Type',
#   <networkx.classes.graph.Graph at 0x253ffa110>): {u'abdulfattah jandalie:Entity',
#   u'atari:Entity',
#   u'jobs:Entity'},
#  (u'view of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x1ec6a6850>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'respiratory arrest:Entity', u'rolling stone interview:Entity'},
#  (u'vision of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252bd8150>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'want:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252ab82d0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'want:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253d35fd0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wanted:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253573110>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wanted:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253f76a10>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wanted:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253f769d0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wanted:Predicate:4',
#   <networkx.classes.graph.Graph at 0x253f76b90>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'was in:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253cf6e10>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'was in:Predicate:3',
#   <networkx.classes.graph.Graph at 0x253f76e10>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'was on:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253f76ed0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'was with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2537b0150>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'went:Predicate:2',
#   <networkx.classes.graph.Graph at 0x2537b0bd0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'were among:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253b5c610>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'wife laurene:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ffa350>): {u'1958:Entity',
#   u'_ page 165:Entity',
#   u'_ page _ title february 24 , 1955:Entity',
#   u'abdulfattah john jandali:Entity',
#   u'joanne simpson:Entity',
#   u'parents:Entity',
#   u'san francisco:Entity',
#   u'two university of wisconsin graduate students:Entity'},
#  (u'wife:Predicate:1',
#   <networkx.classes.graph.Graph at 0x2533f9810>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wins:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ffa750>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wins:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253ffa890>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'woodside mansion:Entity',
#   <networkx.classes.graph.Graph at 0x2532c6810>): {u'abdulfattah jandalie:Entity', u'jobs:Entity', u'woodside mansion:Entity'},
#  (u'worked with:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ffa8d0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'working:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253ffaa10>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'wozniak jobs:Entity',
#   <networkx.classes.graph.Graph at 0x253ffaad0>): {u'abdulfattah jandalie:Entity', u'jobs:Entity'},
#  (u'writer steve martin:Entity',
#   <networkx.classes.graph.Graph at 0x253ffac10>): {u'adoptive families steven paul jobs:Entity',
#   u'apple:Entity',
#   u'birth:Entity',
#   u'february 24 , 1955:Entity',
#   u'honors:Entity',
#   u'joanne schieble:Entity',
#   u'move:Entity'},
#  (u'writes that:Predicate:1',
#   <networkx.classes.graph.Graph at 0x253a8c3d0>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'writes that:Predicate:2',
#   <networkx.classes.graph.Graph at 0x253ffad50>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'},
#  (u'wrote of:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252ce3c50>): {u'abdulfattah jandalie:Entity', u'iger:Entity', u'jobs:Entity'},
#  (u'wrote:Predicate:1',
#   <networkx.classes.graph.Graph at 0x252a4f390>): {u'abdulfattah jandalie:Entity', u'iger:Entity', u'jobs:Entity'},
#  (u'yesterday:Entity',
#   <networkx.classes.graph.Graph at 0x253ffae90>): {u'1983:Entity', u'1994:Entity', u'adoptive families steven paul jobs:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'imagination:Entity', u'joanne schieble:Entity', u'memory:Entity', u'rolling stone interview:Entity', u'yesterday:Entity'},
#  (u'young steve jobs:Entity',
#   <networkx.classes.graph.Graph at 0x254049250>): {u'adoptive families steven paul jobs:Entity', u'apple:Entity', u'birth:Entity', u'february 24 , 1955:Entity', u'honors:Entity', u'joanne schieble:Entity', u'move:Entity'},
#  (u'\u2019s:Predicate:1',
#   <networkx.classes.graph.Graph at 0x254049310>): {u'1958:Entity', u'_ page 165:Entity', u'_ page _ title february 24 , 1955:Entity', u'abdulfattah john jandali:Entity', u'joanne simpson:Entity', u'parents:Entity', u'san francisco:Entity', u'two university of wisconsin graduate students:Entity'}}

# %%
# Find unique sets of answers
ans_set = set()
done = set()
for (v1, T1) in tree_pot:
    for n1 in tree_pot[(v1, T1)]:
        if n1 not in done:
            curr = set()
            q = Queue.Queue()
            q.put(n1)
            while not q.empty():
                nn = q.get()
                curr.add(nn)
                done.add(nn)
                if nn in match:
                    for n2 in match[nn]:
                        if n2 not in curr and n2 not in q.queue:
                            q.put(n2)

            ans_set.add(frozenset(curr))

# %%
def get_corner_wt(ans_set, tree_pot, G, corner, gt1):
    # Add weights to answers
    done = set()
    answer_list = []
    candidate_match_flag = 0
    for ans in ans_set:
        w = 0.0
        support = set()
        for (v1, T1) in tree_pot:
            for n1 in tree_pot[(v1, T1)]:
                if n1 in ans:
                    w += get_cornerstone_weight(T1, G, corner)
                    sent = get_edge_sentid_GST(T1, G)
                    support = support.union(sent)

        anslist = list(ans)
        s = anslist[0]
        for i in range(1, len(anslist)):
            s = s + '|' + anslist[i]
        answer_list.append((s, support, w))

        for gt in gt1:
            for i in range(0, len(anslist)):
                nnc1 = anslist[i].split(':')
                # if nnc1[0]==gt.lower():
                #	candidate_match_flag=1
                if len(nnc1) > 0:
                    if nnc1[0] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1
                else:
                    if anslist[i] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1

    answer_list = sorted(answer_list, key=lambda x: x[2], reverse=True)
    top_match_flag = 0
    for i in range(0, 5):
        if i >= len(answer_list):
            break
        nnc1 = answer_list[0][0].split(':')

        ans1 = answer_list[i][0].split('|')
        for s in ans1:
            s = s.split(':')[0]
            s = s.strip()
            s = s.strip(',')
            # s=s.encode('utf-8')

            for gt in gt1:
                if s == (gt.lower()).decode('utf-8'):
                    top_match_flag = 1
    if top_match_flag == 0:
        for i in range(4, len(answer_list)):
            if answer_list[i][2] == answer_list[4][2]:  # same score as the 5th one
                ans1 = answer_list[i][0].split('|')
                for s in ans1:
                    s = s.split(':')[0]
                    s = s.strip()
                    s = s.strip(',')
                    # s=s.encode('utf-8')

                    for gt in gt1:
                        if s == (gt.lower()).decode('utf-8'):
                            top_match_flag = 1
            else:
                break
    # if verbose:
    if verbose:
        print "\n\nFinal answer ranking --->", len(answer_list)  # ,answer_list
    return answer_list, candidate_match_flag, top_match_flag

# %%
answer_list, candidate_match_flag1, top_match_flag1 = get_corner_wt(ans_set, tree_pot, G, corner, gt1)
str1 = f5 + '_node_wt'
# pickle.dump(answer_list, open(str1, 'w'))

# %%
def get_tree_cost(ans_set, tree_pot, G, corner, gt1):
    # Add weights to answers
    done = set()
    answer_list = []
    candidate_match_flag = 0
    for ans in ans_set:
        w = 0.0
        support = set()
        for (v1, T1) in tree_pot:
            for n1 in tree_pot[(v1, T1)]:
                if n1 in ans:
                    cost_tree = float(get_cost(T1, G))
                    if cost_tree > 0.0:
                        w += 1.0 / cost_tree  # get_cornerstone_weight(T1, G, corner)
                    sent = get_edge_sentid_GST(T1, G)
                    support = support.union(sent)

        anslist = list(ans)
        s = anslist[0]
        for i in range(1, len(anslist)):
            s = s + '|' + anslist[i]
        answer_list.append((s, support, w))

        for gt in gt1:
            for i in range(0, len(anslist)):
                nnc1 = anslist[i].split(':')
                # if nnc1[0]==gt.lower():
                #	candidate_match_flag=1
                if len(nnc1) > 0:
                    if nnc1[0] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1
                else:
                    if anslist[i] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1

    answer_list = sorted(answer_list, key=lambda x: x[2], reverse=True)
    top_match_flag = 0
    for i in range(0, 5):
        if i >= len(answer_list):
            break
        nnc1 = answer_list[0][0].split(':')
        ans1 = answer_list[i][0].split('|')
        for s in ans1:
            s = s.split(':')[0]
            s = s.strip()
            s = s.strip(',')
            # s=s.encode('utf-8')

            for gt in gt1:
                if s == (gt.lower()).decode('utf-8'):
                    top_match_flag = 1
    if top_match_flag == 0:
        for i in range(4, len(answer_list)):
            if answer_list[i][2] == answer_list[4][2]:  # same score as the 5th one
                ans1 = answer_list[i][0].split('|')
                for s in ans1:
                    s = s.split(':')[0]
                    s = s.strip()
                    s = s.strip(',')
                    # s=s.encode('utf-8')

                    for gt in gt1:
                        if s == (gt.lower()).decode('utf-8'):
                            top_match_flag = 1
            else:
                break
    if verbose:
        print "\n\nFinal answer ranking --->", len(answer_list)  # ,answer_list
    return answer_list, candidate_match_flag, top_match_flag

# %%
answer_list, candidate_match_flag2, top_match_flag2 = get_tree_cost(ans_set, tree_pot, G, corner, gt1)
str1 = f5 + '_tree_cost'
# pickle.dump(answer_list, open(str1, 'w'))

# %%
def get_tree_count(ans_set, tree_pot, G, corner, gt1):
    # Add weights to answers
    done = set()
    answer_list = []
    candidate_match_flag = 0
    for ans in ans_set:
        w = 0.0
        support = set()
        for (v1, T1) in tree_pot:
            for n1 in tree_pot[(v1, T1)]:
                if n1 in ans:
                    w += 1.0  # get_cornerstone_weight(T1, G, corner)
                    sent = get_edge_sentid_GST(T1, G)
                    support = support.union(sent)

        anslist = list(ans)
        s = anslist[0]
        for i in range(1, len(anslist)):
            s = s + '|' + anslist[i]
        answer_list.append((s, support, w))

        for gt in gt1:
            for i in range(0, len(anslist)):
                nnc1 = anslist[i].split(':')
                # if nnc1[0]==gt.lower():
                #	candidate_match_flag=1
                if len(nnc1) > 0:
                    if nnc1[0] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1
                else:
                    if anslist[i] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1

    answer_list = sorted(answer_list, key=lambda x: x[2], reverse=True)
    top_match_flag = 0
    for i in range(0, 5):
        if i >= len(answer_list):
            break
        nnc1 = answer_list[0][0].split(':')

        ans1 = answer_list[i][0].split('|')
        for s in ans1:
            s = s.split(':')[0]
            s = s.strip()
            s = s.strip(',')
            # s=s.encode('utf-8')

            for gt in gt1:
                if s == (gt.lower()).decode('utf-8'):
                    top_match_flag = 1
    if top_match_flag == 0:
        for i in range(4, len(answer_list)):
            if answer_list[i][2] == answer_list[4][2]:  # same score as the 5th one
                ans1 = answer_list[i][0].split('|')
                for s in ans1:
                    s = s.split(':')[0]
                    s = s.strip()
                    s = s.strip(',')
                    # s=s.encode('utf-8')

                    for gt in gt1:
                        if s == (gt.lower()).decode('utf-8'):
                            top_match_flag = 1
            else:
                break
    if verbose:
        print "\n\nFinal answer ranking --->", len(answer_list)  # ,answer_list
    return answer_list, candidate_match_flag, top_match_flag

# %%
answer_list, candidate_match_flag3, top_match_flag3 = get_tree_count(ans_set, tree_pot, G, corner, gt1)
str1 = f5 + '_tree_count'
# pickle.dump(answer_list, open(str1, 'w'))

# %%
def get_corner_dist(ans_set, tree_pot, G, corner, gt1):
    # Add weights to answers
    done = set()
    answer_list = []
    candidate_match_flag = 0
    for ans in ans_set:
        w = 0.0
        support = set()
        for (v1, T1) in tree_pot:
            for n1 in tree_pot[(v1, T1)]:
                if n1 in ans:
                    dist_corner = float(get_cornerstone_distance(T1, G, corner, n1))
                    if dist_corner > 0.0:
                        w += 1.0 / dist_corner  # get_cornerstone_weight(T1, G, corner)
                    sent = get_edge_sentid_GST(T1, G)
                    support = support.union(sent)

        anslist = list(ans)
        s = anslist[0]
        for i in range(1, len(anslist)):
            s = s + '|' + anslist[i]
        answer_list.append((s, support, w))

        for gt in gt1:
            for i in range(0, len(anslist)):
                nnc1 = anslist[i].split(':')
                # if nnc1[0]==gt.lower():
                #	candidate_match_flag=1
                if len(nnc1) > 0:
                    if nnc1[0] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1
                else:
                    if anslist[i] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1

    answer_list = sorted(answer_list, key=lambda x: x[2], reverse=True)
    top_match_flag = 0
    for i in range(0, 5):
        if i >= len(answer_list):
            break
        nnc1 = answer_list[0][0].split(':')

        ans1 = answer_list[i][0].split('|')
        for s in ans1:
            s = s.split(':')[0]
            s = s.strip()
            s = s.strip(',')
            # s=s.encode('utf-8')

            for gt in gt1:
                if s == (gt.lower()).decode('utf-8'):
                    top_match_flag = 1
    if top_match_flag == 0:
        for i in range(4, len(answer_list)):
            if answer_list[i][2] == answer_list[4][2]:  # same score as the 5th one
                ans1 = answer_list[i][0].split('|')
                for s in ans1:
                    s = s.split(':')[0]
                    s = s.strip()
                    s = s.strip(',')
                    # s=s.encode('utf-8')

                    for gt in gt1:
                        if s == (gt.lower()).decode('utf-8'):
                            top_match_flag = 1
            else:
                break
    if verbose:
        print "\n\nFinal answer ranking --->", len(answer_list)  # ,answer_list
    return answer_list, candidate_match_flag, top_match_flag

# %%
answer_list, candidate_match_flag4, top_match_flag4 = get_corner_dist(ans_set, tree_pot, G, corner, gt1)
str1 = f5 + '_corner_dist'
# pickle.dump(answer_list, open(str1, 'w'))

# %%
def get_corner_dist_wt(ans_set, tree_pot, G, corner, gt1):
    # Add weights to answers
    done = set()
    answer_list = []
    candidate_match_flag = 0
    for ans in ans_set:
        w = 0.0
        support = set()
        for (v1, T1) in tree_pot:
            for n1 in tree_pot[(v1, T1)]:
                if n1 in ans:
                    dist_corner = float(get_cornerstone_distance_wt(T1, G, corner, n1))
                    if dist_corner > 0.0:
                        w += 1.0 / dist_corner  # get_cornerstone_weight(T1, G, corner)
                    sent = get_edge_sentid_GST(T1, G)
                    support = support.union(sent)

        anslist = list(ans)
        s = anslist[0]
        for i in range(1, len(anslist)):
            s = s + '|' + anslist[i]
        answer_list.append((s, support, w))

        for gt in gt1:
            for i in range(0, len(anslist)):
                nnc1 = anslist[i].split(':')
                # if nnc1[0]==gt.lower():
                #	candidate_match_flag=1
                if len(nnc1) > 0:
                    if nnc1[0] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1
                else:
                    if anslist[i] == (gt.lower()).decode('utf-8'):
                        candidate_match_flag = 1

    answer_list = sorted(answer_list, key=lambda x: x[2], reverse=True)
    top_match_flag = 0
    for i in range(0, 5):
        if i >= len(answer_list):
            break
        nnc1 = answer_list[0][0].split(':')

        ans1 = answer_list[i][0].split('|')
        for s in ans1:
            s = s.split(':')[0]
            s = s.strip()
            s = s.strip(',')
            # s=s.encode('utf-8')

            for gt in gt1:
                if s == (gt.lower()).decode('utf-8'):
                    top_match_flag = 1
    if top_match_flag == 0:
        for i in range(4, len(answer_list)):
            if answer_list[i][2] == answer_list[4][2]:  # same score as the 5th one
                ans1 = answer_list[i][0].split('|')
                for s in ans1:
                    s = s.split(':')[0]
                    s = s.strip()
                    s = s.strip(',')
                    # s=s.encode('utf-8')

                    for gt in gt1:
                        if s == (gt.lower()).decode('utf-8'):
                            top_match_flag = 1
            else:
                break
    if verbose:
        print "\n\nFinal answer ranking --->", len(answer_list)  # ,answer_list
    return answer_list, candidate_match_flag, top_match_flag

# %%
answer_list, candidate_match_flag5, top_match_flag5 = get_corner_dist_wt(ans_set, tree_pot, G, corner, gt1)
str1 = f5 + '_corner_dist_wt'
# pickle.dump(answer_list, open(str1, 'w'))

# %%
len(G.nodes()), len(G.edges()), match_flag, candidate_match_flag1, top_match_flag1, candidate_match_flag2, top_match_flag2, candidate_match_flag3, top_match_flag3, candidate_match_flag4, top_match_flag4, candidate_match_flag5, top_match_flag5
