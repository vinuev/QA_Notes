# %%
import requests
import pickle
import json
import re
import urllib2
from bs4 import BeautifulSoup
import signal
import time

# %% [markdown]
# ## Codes_docs_Crawl get_top10_GOOGLE

# %% [markdown]
# ## 1-get google's related item

# %%
query='https://www.googleapis.com/customsearch/v1?key=AIzaSyBVB31PBqr7OBjunIjq8iPNb5L75pzTxzg&cx=000764406663250367259:rtvytnbpauk&q=When Steve Jobs born &start=1'

# %%
result = requests.get(query)

# %%
r=result.json()

# %%
r
# Out:
# {u'context': {u'title': u'*.google'},
#  u'items': [{u'cacheId': u'cvmgKjU7_-0J',
#    u'displayLink': u'en.wikipedia.org',
#    u'formattedUrl': u'https://en.wikipedia.org/wiki/Steve_Jobs',
#    u'htmlFormattedUrl': u'https://en.wikipedia.org/wiki/<b>Steve</b>_<b>Jobs</b>',
#    u'htmlSnippet': u'<b>Steven</b> Paul <b>Jobs</b> was an American business magnate, industrial designer, <br>\ninvestor, and media ... <b>Steven</b> Paul <b>Jobs</b> was <b>born</b> on February 24, 1955, to <br>\nAbdulfattah Jandali and Joanne Schieble, and was adopted by Paul and Clara <br>\n<b>Jobs</b> (n\xe9e&nbsp;...',
#    u'htmlTitle': u'<b>Steve Jobs</b> - Wikipedia',
#    u'kind': u'customsearch#result',
#    u'link': u'https://en.wikipedia.org/wiki/Steve_Jobs',
#    u'pagemap': {u'cse_image': [{u'src': u'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Steve_Jobs_Headshot_2010-CROP2.jpg/1200px-Steve_Jobs_Headshot_2010-CROP2.jpg'}],
#     u'cse_thumbnail': [{u'height': u'284',
# ...

# %%
r['items'][0]['kind']
# Out:
# u'customsearch#result'

# %%
r['items']
# Out:
# [{u'cacheId': u'cvmgKjU7_-0J',
#   u'displayLink': u'en.wikipedia.org',
#   u'formattedUrl': u'https://en.wikipedia.org/wiki/Steve_Jobs',
#   u'htmlFormattedUrl': u'https://en.wikipedia.org/wiki/<b>Steve</b>_<b>Jobs</b>',
#   u'htmlSnippet': u'<b>Steven</b> Paul <b>Jobs</b> was an American business magnate, industrial designer, <br>\ninvestor, and media ... <b>Steven</b> Paul <b>Jobs</b> was <b>born</b> on February 24, 1955, to <br>\nAbdulfattah Jandali and Joanne Schieble, and was adopted by Paul and Clara <br>\n<b>Jobs</b> (n\xe9e&nbsp;...',
#   u'htmlTitle': u'<b>Steve Jobs</b> - Wikipedia',
#   u'kind': u'customsearch#result',
#   u'link': u'https://en.wikipedia.org/wiki/Steve_Jobs',
#   u'pagemap': {u'cse_image': [{u'src': u'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Steve_Jobs_Headshot_2010-CROP2.jpg/1200px-Steve_Jobs_Headshot_2010-CROP2.jpg'}],
#    u'cse_thumbnail': [{u'height': u'284',
# ...

# %% [markdown]
# ## 2-get all links of related item

# %%
for doc in r['items']:
    print "******DOC******\n",doc,"\n******DOC******\n"
    print "******LINK******\n",doc['link'], "\n******LINK******\n",
# Out:
# ******DOC******
# ...

# %%
r['items'][0]
# Out:
# {u'cacheId': u'cvmgKjU7_-0J',
#  u'displayLink': u'en.wikipedia.org',
#  u'formattedUrl': u'https://en.wikipedia.org/wiki/Steve_Jobs',
#  u'htmlFormattedUrl': u'https://en.wikipedia.org/wiki/<b>Steve</b>_<b>Jobs</b>',
#  u'htmlSnippet': u'<b>Steven</b> Paul <b>Jobs</b> was an American business magnate, industrial designer, <br>\ninvestor, and media ... <b>Steven</b> Paul <b>Jobs</b> was <b>born</b> on February 24, 1955, to <br>\nAbdulfattah Jandali and Joanne Schieble, and was adopted by Paul and Clara <br>\n<b>Jobs</b> (n\xe9e&nbsp;...',
#  u'htmlTitle': u'<b>Steve Jobs</b> - Wikipedia',
#  u'kind': u'customsearch#result',
#  u'link': u'https://en.wikipedia.org/wiki/Steve_Jobs',
#  u'pagemap': {u'cse_image': [{u'src': u'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Steve_Jobs_Headshot_2010-CROP2.jpg/1200px-Steve_Jobs_Headshot_2010-CROP2.jpg'}],
#   u'cse_thumbnail': [{u'height': u'284',
# ...

# %%
r['items'][0]['link']
# Out:
# u'https://en.wikipedia.org/wiki/Steve_Jobs'

# %% [markdown]
# ## 3-read text of link

# %%
html = urllib2.urlopen(r['items'][0]['link']).read()
html
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Steve Jobs - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XkfuxApAICIAACDms6gAAAAO","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Steve_Jobs","wgTitle":"Steve Jobs","wgCurRevisionId":940811252,"wgRevisionId":940811252,"wgArticleId":7412236,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia articles needing page number citations from April 2017","CS1 maint: archive
# ...

# %%
soup = BeautifulSoup(html,"lxml")
soup
# Out:
# <!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n<head>\n<meta charset="unicode-escape"/>\n<title>Steve Jobs - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XkfuxApAICIAACDms6gAAAAO","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Steve_Jobs","wgTitle":"Steve Jobs","wgCurRevisionId":940811252,"wgRevisionId":940811252,"wgArticleId":7412236,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia articles needing page number citations from April 2017","CS1 maint:
# ...

# %% [markdown]
# ## 4-clean and save the text of link

# %%
data = soup.findAll(text=True)
data
# Out:
# [u'html',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'Steve Jobs - Wikipedia',
#  u'\n',
# ...

# %%
def visible(element):
	if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
		return False
	elif re.match('<!--.*-->', str(element.encode('utf-8'))):
		return False
	return True

# %%
result = list(filter(visible, data))
result
# Out:
# [u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u' CentralNotice ',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'Steve Jobs',
#  u'\n',
#  u'\n',
#  u'From Wikipedia, the free encyclopedia',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'Jump to navigation',
#  u'\n',
#  u'Jump to search',
#  u'\n',
#  u'This article is about the person. For other uses, see ',
#  u'Steve Jobs (disambiguation)',
#  u'.',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'American entrepreneur and co-founder of Apple Inc.',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'Steve Jobs',
#  u'Jobs in 2010',
#  u'Born',
#  u'Steven Paul Jobs',
#  u'(',
#  u'1955-02-24',
#  u')',
#  u'February 24, 1955',
#  u'San Francisco',
#  u', ',
#  u'California',
#  u', U.S.',
#  u'Died',
#  u'October 5, 2011',
#  u'(2011-10-05)',
#  u' (aged\xa056)',
#  u'Palo Alto, California',
#  u', U.S.',
#  u'Cause\xa0of death',
#  u'Neuroendocrine cancer',
#  u'Resting place',
#  u'Alta Mesa Memorial Park',
#  u'Occupation',
#  u'\n',
# ...

# %%
def process(result):
	result1=''
	for elem in result:
		if elem.count(' ') <= 1:
			continue
		elem=elem.strip('\n')
		elem=elem.strip('\t')
		elem=elem.strip('\r')	
		result1+=' '+elem
	return result1

# %%
result1=process(result)
result1
# Out:
# u'  CentralNotice  From Wikipedia, the free encyclopedia Jump to navigation Jump to search This article is about the person. For other uses, see  Steve Jobs (disambiguation) American entrepreneur and co-founder of Apple Inc. Jobs in 2010 Steven Paul Jobs February 24, 1955 October 5, 2011 Palo Alto, California Alta Mesa Memorial Park Pioneer of the  personal computer revolution  with  Co-creator of the  , and first  US$7 billion (September 2011) Co-founder, Chairman, and CEO of  Primary investor and Chairman of  Founder, Chairman, and CEO of  The Walt Disney Company 4, including  Steven Paul Jobs ; February 24, 1955 \u2013 October 5, 2011) was an American  , and  . He was the chairman, chief executive officer (CEO), and co-founder of  , the chairman and majority shareholder of  , a member of  The Walt Disney Company \'s board of directors following its acquisition of Pixar, and the founder, chairman, and CEO of  . Jobs is widely recognized as a pioneer of the  personal computer revolu
# ...

# %%
# write into file
# fp=open('./docs/link_wise_docs_'+q+'.json','w')
# fp.write(json.dumps({'link':doc['link'],'doc':result1.encode('utf-8')}))
# fp.write('\n')
# fp1=open('./docs/doc'+str(crawled)+'.txt','w')
# fp1.write(doc['link']+'\n')
# fp1.write(result1.encode('utf-8'))
# fp1.close()
